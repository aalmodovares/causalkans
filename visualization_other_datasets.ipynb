# %% [markdown]
# #  Other datasets
#
# For the other dataset: IHDP B and ACIC 2, the obtained models are TARNKAAM and DragonKAM, which yield more complex functions, and therefore
# more advanced visualization tools should be developed

# %% [markdown]
# # IHDP B

# %%
#imports
import numpy as np
import pandas as pd
import torch
import time

from utils import load_data
from sklearn.model_selection import train_test_split
from kan import ex_round
from kan_model import kan_net
from mlp_model import mlp_net
from utils import get_width, get_dims_mlp
from representation import *
from tueplots import bundles, figsizes, axes
import copy
import matplotlib.pyplot as plt
from experiment_symbolic import *

# %%
# seed
np.random.seed(42)
torch.manual_seed(42)

# %%
#load the data
i = 2
split = 0.2

data_train, data_test = load_data('IHDP_B', i)
col_names = data_train.columns
x_cols = [col for col in data_train.columns if 'x' in col]

x_train, y_train, t_train = data_train[x_cols].values, data_train['y_factual'].values[:, None], data_train['treatment'].values[:, None]
x_test, y_test, t_test = data_test[[col for col in data_test.columns if 'x' in col]].values, data_test['y_factual'].values[:, None], data_test['treatment'].values[:, None]

x_train, x_val, y_train, y_val, t_train, t_val = train_test_split(x_train, y_train, t_train, test_size=split, shuffle=False)

real_ite_train = data_train['mu1'].values - data_train['mu0'].values
real_ite_test = data_test['mu1'].values - data_test['mu0'].values

real_ite_train, real_ite_val = real_ite_train[:x_train.shape[0]], real_ite_train[x_train.shape[0]:]
print(col_names)
print(x_cols)

data_test_t0 = data_test.copy()
data_test_t0['treatment'] = 0
data_test_t1 = data_test.copy()
data_test_t1['treatment'] = 1
# Out:
# Index(['treatment', 'y_factual', 'y_cfactual', 'mu0', 'mu1', 'x1', 'x2', 'x3',
#        'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14',
#        'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24',
#        'x25'],
#       dtype='object')
# ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25']

# %%
# preprocess the data
print(x_train.shape, y_train.shape, t_train.shape, x_val.shape, y_val.shape, t_val.shape, x_test.shape, y_test.shape, t_test.shape, real_ite_train.shape, real_ite_test.shape, real_ite_val.shape)
# Out:
# (418, 25) (418, 1) (418, 1) (105, 25) (105, 1) (105, 1) (224, 25) (224, 1) (224, 1) (418,) (224,) (105,)

# %%
# instanciate the KAN model
# T-KAAM
width = get_width('dragonnet', x_train.shape[1], hidden_dims = [5], mult_kan=True)
dragon_kaam_ihdp = kan_net('dragonnet', width, grid=3, k=3, sparse_init=False, try_gpu=False, real_ite_train=real_ite_train, real_ite_test=real_ite_val, save_folder='visualization/checkpoint')
# Out:
# checkpoint directory created: C:\Users\Alex\CODE\causalkans\visualization/checkpoint\kan_345353\
# saving model version 0.0

# %%
#train the model
tic = time.time()
results = dragon_kaam_ihdp.fit(x_train, y_train, t_train, x_val, y_val, t_val, early_stop=True, patience=30, batch=1000,
                           steps=10000, lamb=0.01, lamb_entropy=0.1,  lr=0.001, verbose=0)
tac = time.time()
print(results.keys())
print('Training time: ', tac - tic)
# Out:
# Early stopping at step 1192
# saving model version 0.1
# dict_keys(['train_loss', 'test_loss', 'reg', 'train_metrics', 'test_metrics'])
# Training time:  49.44813585281372

# %%
prediction = dragon_kaam.predict(x_test, t_test)
print(prediction.keys())
prediction['ite']= prediction['y_pred_1'] - prediction['y_pred_0']
# Out:
# dict_keys(['y_pred_0', 'y_pred_1', 'y_pred_f', 'y_pred_cf', 'ps_pred', 'pred_best_treatment'])

# %%
# Compute prediction metrics in MSE of factual outcome and
mse = np.mean((y_test - prediction['y_pred_f'])**2)
pehe = np.sqrt(np.mean((real_ite_test - prediction['ite'])**2))
print(f'MSE original KAN: {mse}, PEHE original KAN: {pehe}')
print(f'Predicted ATE: {prediction["ite"].mean()}, Real ATE: {real_ite_test.mean()}')
# Out:
# MSE original KAN: 23.81933951374525, PEHE original KAN: 2.7240276773958003
# Predicted ATE: 3.559431314468384, Real ATE: 3.826578597130422

# %%
# MLP params = hidden_dims= [100, 100, 100], dropout=0.0, lr=1e-05, activation=leaky_relu
dims_mlp = get_dims_mlp('dragonnet', x_train.shape[1], hidden_dims=[[200, 200, 200], [100, 100], []])
dragon_nn = mlp_net('dragonnet', dims_mlp, dropout=0.0, activation='elu', try_gpu=False, save_folder='visualization/checkpoint', real_ite_train = real_ite_train, real_ite_test = real_ite_val)
tic = time.time()
results_mlp = dragon_nn.fit(x_train, y_train, t_train, x_val, y_val, t_val, early_stop=True, patience=30, batch=1000,
                           steps=10000, lr=1e-5, verbose=0)
tac = time.time()
print(results_mlp.keys())
print('Training time MLP: ', tac - tic)
# Out:
# Early stopping at step 8994
# dict_keys(['train_loss', 'test_loss', 'reg', 'train_metrics', 'test_metrics'])
# Training time MLP:  198.2119972705841

# %%
prediction_mlp = dragon_nn.predict(x_test, t_test)
prediction_mlp['ite']= prediction_mlp['y_pred_1'] - prediction_mlp['y_pred_0']
mse_mlp = np.mean((y_test - prediction_mlp['y_pred_f'])**2)
pehe_mlp = np.sqrt(np.mean((real_ite_test - prediction_mlp['ite'])**2))
print(f'MSE MLP: {mse_mlp}, PEHE MLP: {pehe_mlp}')
print(f'ATE MLP: {prediction_mlp["ite"].mean()}, Real ATE: {real_ite_test.mean()}')
# Out:
# MSE MLP: 25.93584607590749, PEHE MLP: 2.455876843100015
# ATE MLP: 3.401909351348877, Real ATE: 3.826578597130422

# %%
print(results.keys())
# Out:
# dict_keys(['train_loss', 'test_loss', 'reg', 'train_metrics', 'test_metrics'])

# %%
# formula without pruning
# symb_s_kaam_orig = symbolic_kan_regressor(x_names = x_cols, y_names=['mu_0', 'mu_1', 'propensity'])

# %%
# with plt.rc_context({**bundles.iclr2024()}):
#     tic = time.time()
#     xt_train = np.concatenate((x_train, t_train), axis=1)
#     xt_val = np.concatenate((x_val, t_val), axis=1)
#     # out_0 = symb_s_kaam_orig.fit(dragon_kaam.model, xt_train, y_train, xt_val, y_val, denorm_function=None, stochastic=False, r2_threshold=0.98, show_results=False, save_dir = 'visualization/formulas')
#     out_0 = symb_s_kaam_orig.fit(dragon_kaam.model, x_train, y_train, x_val, y_val, denorm_function=None, stochastic=False, r2_threshold=0.98, show_results=False, save_dir = 'visualization/formulas')
#     tac = time.time()
#     print('Formula extraction time (control): ', tac - tic)
#
# formulas_orig = symb_s_kaam_orig.get_formula()

# %%
# print(formulas_orig[0])

# %%
# print(formulas_orig[0])

# %% [markdown]
#  # PRUNING AND FORMULA EXTRACTION

# %%
# pruning and evaluation
# t_kaam_original = copy.deepcopy(t_kaam)
tic = time.time()
dragon_kaam_ihdp_pruned = dragon_kaam_ihdp.prune(node_th=1e-2, edge_th=1e-2)
tac = time.time()
print('Pruning time: ', tac - tic)
# Out:
# saving model version 0.2
# Pruning time:  0.05620169639587402

# %%
#evaluate
predictions_pruned = dragon_kaam_ihdp.predict(x_test, t_test)
predictions_pruned['ite']= predictions_pruned['y_pred_1'] - predictions_pruned['y_pred_0']
mse_pruned = np.mean((y_test - predictions_pruned['y_pred_f'])**2)
pehe_pruned = np.sqrt(np.mean((real_ite_test - predictions_pruned['ite'])**2))
print(f'MSE pruned KAN: {mse_pruned}, PEHE pruned KAN: {pehe_pruned}')
print(f'Predicted ATE: {predictions_pruned["ite"].mean()}, Real ATE: {real_ite_test.mean()}')
# Out:
# MSE pruned KAN: 27.874434246228944, PEHE pruned KAN: 2.6958143339238805
# Predicted ATE: 3.3271918296813965, Real ATE: 3.826578597130422

# %%
# # formula extraction
# symb_s_kaam = symbolic_kan_regressor(x_names = x_cols, y_names=['mu_0', 'mu_1', 'propensity'])
# with plt.rc_context({**bundles.iclr2024()}):
#     tic = time.time()
#     xt_train = np.concatenate((x_train, t_train), axis=1)
#     xt_val = np.concatenate((x_val, t_val), axis=1)
#     # out_0 = symb_s_kaam.fit(dragon_kaam.model, xt_train, y_train, xt_val, y_val, denorm_function=None, stochastic=False, r2_threshold=0.98, show_results=False, save_dir = 'visualization/formulas')
#     out_0 = symb_s_kaam.fit(dragon_kaam.model, x_train, y_train, x_val, y_val, denorm_function=None, stochastic=False, r2_threshold=0.98, show_results=False, save_dir = 'visualization/formulas')
#     tac = time.time()
#     print('Formula extraction time (control): ', tac - tic)
# formulas = symb_s_kaam.get_formula()

# %%
formulas = dragon_kaam_ihdp.interprete('all', n_digit=4)
# Out:
# Using library all
# fixing (0,0,0) with sin, r2=0.9976866245269775, c=2
# fixing (0,0,1) with sin, r2=0.9992488026618958, c=2
# fixing (0,0,2) with sin, r2=0.9837432503700256, c=2
# fixing (0,0,3) with x, r2=0.988549530506134, c=1
# fixing (0,0,4) with sin, r2=0.9991015791893005, c=2
# fixing (0,0,5) with x, r2=0.9428504705429077, c=1
# fixing (0,0,6) with x^2, r2=0.9985201954841614, c=2
# fixing (0,0,7) with sin, r2=0.9947016835212708, c=2
# fixing (0,0,8) with 0
# fixing (0,0,9) with 0
# fixing (0,0,10) with tanh, r2=0.999727189540863, c=3
# fixing (0,0,11) with 0
# fixing (0,0,12) with sin, r2=0.9998430609703064, c=2
# fixing (0,0,13) with sin, r2=0.9996123313903809, c=2
# fixing (0,1,0) with 0
# fixing (0,1,1) with x, r2=0.9902762770652771, c=1
# fixing (0,1,2) with sin, r2=0.9884856343269348, c=2
# fixing (0,1,3) with sin, r2=0.9909999370574951, c=2
# fixing (0,1,4) with sin, r2=0.9946965575218201, c=2
# fixing (0,1,5) with sin, r2=0.994387149810791, c=2
# fixing (0,1,6) with sin, r2=0.9951779246330261, c=2
# fixing (0,1,7) with sin, r2=0.999672532081604, c=2
# fixing (0,1,8) with 0
# fixing (0,1,9) with 0
# fixing (0,1,10) with 0
# fixing (0,1,11) with x, r2=0.8223232626914978, c=1
# fixing (0,1,12) with sin, r2=0.997626543045044, c=2
# fixing (0,1,13) with sin, r2=0.996364951133728, c=2
# fixing (0,2,0) with 0
# fixing (0,2,1) with sin, r2=0.9994888305664062, c=2
# fixing (0,2,2) with sin, r2=0.9910069704055786, c=2
# fixing (0,2,3) with sin, r2=0.9970905780792236, c=2
# fixing (0,2,4) with 0
# fixing (0,2,5) with x, r2=0.9049600958824158, c=1
# fixing (0,2,6) with sin, r2=0.9996191263198853, c=2
# fixing (0,2,7) with sin, r2=0.9992637038230896, c=2
# fixing (0,2,8) with 0
# fixing (0,2,9) with sin, r2=0.9937566518783569, c=2
# fixing (0,2,10) with 0
# fixing (0,2,11) with sin, r2=0.9968247413635254, c=2
# fixing (0,2,12) with sin, r2=0.9921533465385437, c=2
# fixing (0,2,13) with sin, r2=0.998375415802002, c=2
# fixing (0,3,0) with sin, r2=1.000000238418579, c=2
# fixing (0,3,1) with sin, r2=1.0000004768371582, c=2
# fixing (0,3,2) with 0
# fixing (0,3,3) with tan, r2=0.999999463558197, c=3
# fixing (0,3,4) with tan, r2=0.9999995827674866, c=3
# fixing (0,3,5) with tan, r2=0.9999998211860657, c=3
# fixing (0,3,6) with sin, r2=0.9999999403953552, c=2
# fixing (0,3,7) with sin, r2=0.9999987483024597, c=2
# fixing (0,3,8) with 0
# fixing (0,3,9) with sin, r2=0.9999985694885254, c=2
# fixing (0,3,10) with sin, r2=1.0000001192092896, c=2
# fixing (0,3,11) with 0
# fixing (0,3,12) with tan, r2=1.0, c=3
# fixing (0,3,13) with exp, r2=0.999994158744812, c=2
# fixing (0,4,0) with sin, r2=0.9989789128303528, c=2
# fixing (0,4,1) with tanh, r2=0.9997327923774719, c=3
# fixing (0,4,2) with sin, r2=0.9715155363082886, c=2
# fixing (0,4,3) with sin, r2=0.9608888626098633, c=2
# fixing (0,4,4) with sin, r2=0.9436971545219421, c=2
# fixing (0,4,5) with sin, r2=0.963600218296051, c=2
# fixing (0,4,6) with x, r2=0.44272011518478394, c=1
# fixing (0,4,7) with sin, r2=0.9644752144813538, c=2
# fixing (0,4,8) with tanh, r2=0.9998541474342346, c=3
# fixing (0,4,9) with tanh, r2=0.9995724558830261, c=3
# fixing (0,4,10) with x, r2=0.6266541481018066, c=1
# fixing (0,4,11) with x, r2=0.38238176703453064, c=1
# fixing (0,4,12) with sin, r2=0.9869842529296875, c=2
# fixing (0,4,13) with sin, r2=0.991151750087738, c=2
# fixing (0,5,0) with 0
# fixing (0,5,1) with x, r2=0.9928352236747742, c=1
# fixing (0,5,2) with x, r2=0.9777410626411438, c=1
# fixing (0,5,3) with 0
# fixing (0,5,4) with sin, r2=0.999927282333374, c=2
# fixing (0,5,5) with x^2, r2=0.9978590607643127, c=2
# fixing (0,5,6) with x^2, r2=0.999396562576294, c=2
# fixing (0,5,7) with sin, r2=0.9999640583992004, c=2
# fixing (0,5,8) with 0
# fixing (0,5,9) with 0
# fixing (0,5,10) with 0
# fixing (0,5,11) with x, r2=0.8757667541503906, c=1
# fixing (0,5,12) with x, r2=0.9810983538627625, c=1
# fixing (0,5,13) with x, r2=0.9795351028442383, c=1
# fixing (0,6,0) with 0
# fixing (0,6,1) with x, r2=1.0000009536743164, c=1
# fixing (0,6,2) with x, r2=1.0000005960464478, c=1
# fixing (0,6,3) with x, r2=1.0000007152557373, c=1
# fixing (0,6,4) with x, r2=1.0000007152557373, c=1
# fixing (0,6,5) with x, r2=1.0000008344650269, c=1
# fixing (0,6,6) with 0
# fixing (0,6,7) with 0
# fixing (0,6,8) with x, r2=1.0000008344650269, c=1
# fixing (0,6,9) with x, r2=1.0000007152557373, c=1
# fixing (0,6,10) with x, r2=1.0000007152557373, c=1
# fixing (0,6,11) with 0
# fixing (0,6,12) with x, r2=1.0000007152557373, c=1
# fixing (0,6,13) with x, r2=1.000001072883606, c=1
# fixing (0,7,0) with 0
# fixing (0,7,1) with x, r2=1.000001072883606, c=1
# fixing (0,7,2) with x, r2=1.0000009536743164, c=1
# fixing (0,7,3) with 0
# fixing (0,7,4) with 0
# fixing (0,7,5) with x, r2=1.0000007152557373, c=1
# fixing (0,7,6) with x, r2=1.000001072883606, c=1
# fixing (0,7,7) with x, r2=1.0000005960464478, c=1
# fixing (0,7,8) with 0
# fixing (0,7,9) with 0
# fixing (0,7,10) with x, r2=1.000001072883606, c=1
# fixing (0,7,11) with 0
# fixing (0,7,12) with x, r2=1.0000008344650269, c=1
# fixing (0,7,13) with x, r2=1.0000008344650269, c=1
# fixing (0,8,0) with 0
# fixing (0,8,1) with x, r2=1.0000007152557373, c=1
# fixing (0,8,2) with 0
# fixing (0,8,3) with x, r2=1.0000008344650269, c=1
# fixing (0,8,4) with x, r2=1.0000007152557373, c=1
# fixing (0,8,5) with x, r2=1.0000008344650269, c=1
# fixing (0,8,6) with x, r2=1.0000007152557373, c=1
# fixing (0,8,7) with x, r2=1.0000005960464478, c=1
# fixing (0,8,8) with 0
# fixing (0,8,9) with 0
# fixing (0,8,10) with 0
# fixing (0,8,11) with 0
# fixing (0,8,12) with x, r2=1.0000005960464478, c=1
# fixing (0,8,13) with x, r2=1.0000004768371582, c=1
# fixing (0,9,0) with 0
# fixing (0,9,1) with x, r2=1.0000005960464478, c=1
# fixing (0,9,2) with x, r2=1.0000005960464478, c=1
# fixing (0,9,3) with x, r2=1.0000008344650269, c=1
# fixing (0,9,4) with x, r2=1.0000009536743164, c=1
# fixing (0,9,5) with x, r2=1.0000008344650269, c=1
# fixing (0,9,6) with x, r2=1.0000007152557373, c=1
# fixing (0,9,7) with x, r2=1.0000004768371582, c=1
# fixing (0,9,8) with 0
# fixing (0,9,9) with 0
# fixing (0,9,10) with 0
# fixing (0,9,11) with 0
# fixing (0,9,12) with x, r2=1.0000007152557373, c=1
# fixing (0,9,13) with x, r2=1.0000007152557373, c=1
# fixing (0,10,0) with 0
# fixing (0,10,1) with x, r2=1.0000007152557373, c=1
# fixing (0,10,2) with 0
# fixing (0,10,3) with 0
# fixing (0,10,4) with 0
# fixing (0,10,5) with x, r2=1.0000007152557373, c=1
# fixing (0,10,6) with x, r2=1.0000008344650269, c=1
# fixing (0,10,7) with x, r2=1.0000008344650269, c=1
# fixing (0,10,8) with x, r2=1.0000008344650269, c=1
# fixing (0,10,9) with x, r2=1.0000005960464478, c=1
# fixing (0,10,10) with 0
# fixing (0,10,11) with 0
# fixing (0,10,12) with x, r2=1.0000007152557373, c=1
# fixing (0,10,13) with x, r2=1.0000007152557373, c=1
# fixing (0,11,0) with 0
# fixing (0,11,1) with x, r2=1.0000007152557373, c=1
# fixing (0,11,2) with x, r2=1.0000007152557373, c=1
# fixing (0,11,3) with x, r2=1.0000007152557373, c=1
# fixing (0,11,4) with x, r2=1.0000004768371582, c=1
# fixing (0,11,5) with x, r2=1.0000005960464478, c=1
# fixing (0,11,6) with x, r2=1.0000007152557373, c=1
# fixing (0,11,7) with x, r2=1.0000007152557373, c=1
# fixing (0,11,8) with 0
# fixing (0,11,9) with 0
# fixing (0,11,10) with 0
# fixing (0,11,11) with 0
# fixing (0,11,12) with x, r2=1.0000007152557373, c=1
# fixing (0,11,13) with 0
# fixing (0,12,0) with 0
# fixing (0,12,1) with x, r2=1.0000007152557373, c=1
# fixing (0,12,2) with x, r2=1.0000007152557373, c=1
# fixing (0,12,3) with x, r2=1.0000008344650269, c=1
# fixing (0,12,4) with 0
# fixing (0,12,5) with x, r2=1.0000005960464478, c=1
# fixing (0,12,6) with x, r2=1.0000008344650269, c=1
# fixing (0,12,7) with x, r2=1.0000008344650269, c=1
# fixing (0,12,8) with 0
# fixing (0,12,9) with 0
# fixing (0,12,10) with 0
# fixing (0,12,11) with 0
# fixing (0,12,12) with x, r2=1.0000007152557373, c=1
# fixing (0,12,13) with x, r2=1.0000007152557373, c=1
# fixing (0,13,0) with 0
# fixing (0,13,1) with x, r2=1.0000008344650269, c=1
# fixing (0,13,2) with x, r2=1.0000007152557373, c=1
# fixing (0,13,3) with x, r2=1.0000009536743164, c=1
# fixing (0,13,4) with x, r2=1.0000005960464478, c=1
# fixing (0,13,5) with x, r2=1.0000009536743164, c=1
# fixing (0,13,6) with x, r2=1.0000007152557373, c=1
# fixing (0,13,7) with 0
# fixing (0,13,8) with 0
# fixing (0,13,9) with x, r2=1.0000008344650269, c=1
# fixing (0,13,10) with x, r2=1.0000007152557373, c=1
# fixing (0,13,11) with 0
# fixing (0,13,12) with x, r2=1.0000005960464478, c=1
# fixing (0,13,13) with x, r2=1.0000007152557373, c=1
# fixing (0,14,0) with 0
# fixing (0,14,1) with x, r2=1.0000007152557373, c=1
# fixing (0,14,2) with x, r2=1.0000007152557373, c=1
# fixing (0,14,3) with 0
# fixing (0,14,4) with x, r2=1.0000005960464478, c=1
# fixing (0,14,5) with x, r2=1.0000007152557373, c=1
# fixing (0,14,6) with x, r2=1.0000003576278687, c=1
# fixing (0,14,7) with x, r2=1.0000007152557373, c=1
# fixing (0,14,8) with 0
# fixing (0,14,9) with 0
# fixing (0,14,10) with 0
# fixing (0,14,11) with 0
# fixing (0,14,12) with x, r2=1.0000004768371582, c=1
# fixing (0,14,13) with x, r2=1.0000004768371582, c=1
# fixing (0,15,0) with 0
# fixing (0,15,1) with x, r2=1.0000009536743164, c=1
# fixing (0,15,2) with 0
# fixing (0,15,3) with 0
# fixing (0,15,4) with x, r2=1.0000008344650269, c=1
# fixing (0,15,5) with 0
# fixing (0,15,6) with 0
# fixing (0,15,7) with 0
# fixing (0,15,8) with 0
# fixing (0,15,9) with 0
# fixing (0,15,10) with 0
# fixing (0,15,11) with 0
# fixing (0,15,12) with 0
# fixing (0,15,13) with 0
# fixing (0,16,0) with 0
# fixing (0,16,1) with x, r2=1.0000007152557373, c=1
# fixing (0,16,2) with x, r2=1.0000007152557373, c=1
# fixing (0,16,3) with x, r2=1.0000007152557373, c=1
# fixing (0,16,4) with x, r2=1.0000007152557373, c=1
# fixing (0,16,5) with x, r2=1.0000007152557373, c=1
# fixing (0,16,6) with x, r2=1.0000007152557373, c=1
# fixing (0,16,7) with x, r2=1.0000007152557373, c=1
# fixing (0,16,8) with 0
# fixing (0,16,9) with 0
# fixing (0,16,10) with 0
# fixing (0,16,11) with 0
# fixing (0,16,12) with x, r2=1.0000007152557373, c=1
# fixing (0,16,13) with x, r2=1.0000005960464478, c=1
# fixing (0,17,0) with 0
# fixing (0,17,1) with x, r2=1.0000009536743164, c=1
# fixing (0,17,2) with 0
# fixing (0,17,3) with 0
# fixing (0,17,4) with 0
# fixing (0,17,5) with x, r2=1.0000004768371582, c=1
# fixing (0,17,6) with 0
# fixing (0,17,7) with 0
# fixing (0,17,8) with 0
# fixing (0,17,9) with 0
# fixing (0,17,10) with 0
# fixing (0,17,11) with 0
# fixing (0,17,12) with 0
# fixing (0,17,13) with 0
# fixing (0,18,0) with 0
# fixing (0,18,1) with x, r2=1.0000017881393433, c=1
# fixing (0,18,2) with x, r2=1.0000017881393433, c=1
# fixing (0,18,3) with 0
# fixing (0,18,4) with x, r2=1.0000011920928955, c=1
# fixing (0,18,5) with x, r2=1.0000009536743164, c=1
# fixing (0,18,6) with x, r2=1.0000016689300537, c=1
# fixing (0,18,7) with x, r2=1.000002384185791, c=1
# fixing (0,18,8) with 0
# fixing (0,18,9) with 0
# fixing (0,18,10) with 0
# fixing (0,18,11) with 0
# fixing (0,18,12) with 0
# fixing (0,18,13) with x, r2=1.0000015497207642, c=1
# fixing (0,19,0) with 0
# fixing (0,19,1) with 0
# fixing (0,19,2) with 0
# fixing (0,19,3) with x, r2=1.0000016689300537, c=1
# fixing (0,19,4) with 0
# fixing (0,19,5) with 0
# fixing (0,19,6) with x, r2=1.0000017881393433, c=1
# fixing (0,19,7) with x, r2=1.000001072883606, c=1
# fixing (0,19,8) with x, r2=1.0000015497207642, c=1
# fixing (0,19,9) with 0
# fixing (0,19,10) with 0
# fixing (0,19,11) with 0
# fixing (0,19,12) with x, r2=1.000001311302185, c=1
# fixing (0,19,13) with x, r2=1.000001072883606, c=1
# fixing (0,20,0) with 0
# fixing (0,20,1) with x, r2=1.0000007152557373, c=1
# fixing (0,20,2) with 0
# fixing (0,20,3) with x, r2=1.0000009536743164, c=1
# fixing (0,20,4) with x, r2=1.0000005960464478, c=1
# fixing (0,20,5) with 0
# fixing (0,20,6) with x, r2=1.0000009536743164, c=1
# fixing (0,20,7) with x, r2=1.000001311302185, c=1
# fixing (0,20,8) with x, r2=1.0000004768371582, c=1
# fixing (0,20,9) with x, r2=1.0000008344650269, c=1
# fixing (0,20,10) with x, r2=1.000001072883606, c=1
# fixing (0,20,11) with x, r2=1.0000007152557373, c=1
# fixing (0,20,12) with x, r2=1.000001072883606, c=1
# fixing (0,20,13) with x, r2=1.0000009536743164, c=1
# fixing (0,21,0) with 0
# fixing (0,21,1) with 0
# fixing (0,21,2) with x, r2=1.0000008344650269, c=1
# fixing (0,21,3) with x, r2=1.0000008344650269, c=1
# fixing (0,21,4) with x, r2=1.0000007152557373, c=1
# fixing (0,21,5) with x, r2=1.0000007152557373, c=1
# fixing (0,21,6) with x, r2=1.0000005960464478, c=1
# fixing (0,21,7) with x, r2=1.0000005960464478, c=1
# fixing (0,21,8) with 0
# fixing (0,21,9) with 0
# fixing (0,21,10) with x, r2=1.0000007152557373, c=1
# fixing (0,21,11) with 0
# fixing (0,21,12) with x, r2=1.0000008344650269, c=1
# fixing (0,21,13) with x, r2=1.0000005960464478, c=1
# fixing (0,22,0) with 0
# fixing (0,22,1) with 0
# fixing (0,22,2) with 0
# fixing (0,22,3) with 0
# fixing (0,22,4) with 0
# fixing (0,22,5) with 0
# fixing (0,22,6) with 0
# fixing (0,22,7) with x, r2=1.0000014305114746, c=1
# fixing (0,22,8) with 0
# fixing (0,22,9) with 0
# fixing (0,22,10) with 0
# fixing (0,22,11) with 0
# fixing (0,22,12) with x, r2=1.0000009536743164, c=1
# fixing (0,22,13) with x, r2=1.000001311302185, c=1
# fixing (0,23,0) with 0
# fixing (0,23,1) with x, r2=1.0000009536743164, c=1
# fixing (0,23,2) with x, r2=1.0000011920928955, c=1
# fixing (0,23,3) with x, r2=1.0000009536743164, c=1
# fixing (0,23,4) with x, r2=1.0000007152557373, c=1
# fixing (0,23,5) with 0
# fixing (0,23,6) with 0
# fixing (0,23,7) with x, r2=1.000001072883606, c=1
# fixing (0,23,8) with x, r2=1.0000008344650269, c=1
# fixing (0,23,9) with x, r2=1.0000008344650269, c=1
# fixing (0,23,10) with 0
# fixing (0,23,11) with 0
# fixing (0,23,12) with x, r2=1.000001072883606, c=1
# fixing (0,23,13) with x, r2=1.0000008344650269, c=1
# fixing (0,24,0) with x, r2=1.0000005960464478, c=1
# fixing (0,24,1) with x, r2=1.0000008344650269, c=1
# fixing (0,24,2) with x, r2=1.0000007152557373, c=1
# fixing (0,24,3) with x, r2=1.0000008344650269, c=1
# fixing (0,24,4) with x, r2=1.0000008344650269, c=1
# fixing (0,24,5) with x, r2=1.0000007152557373, c=1
# fixing (0,24,6) with x, r2=1.0000007152557373, c=1
# fixing (0,24,7) with x, r2=1.0000008344650269, c=1
# fixing (0,24,8) with 0
# fixing (0,24,9) with 0
# fixing (0,24,10) with 0
# fixing (0,24,11) with 0
# fixing (0,24,12) with x, r2=1.0000009536743164, c=1
# fixing (0,24,13) with x, r2=1.0000008344650269, c=1
# fixing (1,0,0) with 0
# fixing (1,0,1) with x, r2=0.9955184459686279, c=1
# fixing (1,0,2) with x, r2=0.8761802315711975, c=1
# fixing (1,1,0) with x, r2=0.8125283122062683, c=1
# fixing (1,1,1) with x, r2=0.696744978427887, c=1
# fixing (1,1,2) with x, r2=0.6726166009902954, c=1
# fixing (1,2,0) with x, r2=0.5194115042686462, c=1
# fixing (1,2,1) with x, r2=0.7025030255317688, c=1
# fixing (1,2,2) with x, r2=0.004565991461277008, c=1
# fixing (1,3,0) with 0
# fixing (1,3,1) with x, r2=0.9834787845611572, c=1
# fixing (1,3,2) with x, r2=0.9940412044525146, c=1
# fixing (1,4,0) with x, r2=0.999761700630188, c=1
# fixing (1,4,1) with x, r2=0.9988996386528015, c=1
# fixing (1,4,2) with x, r2=0.9568256735801697, c=1
# fixing (1,5,0) with x, r2=0.1895180642604828, c=1
# fixing (1,5,1) with x, r2=0.1749141663312912, c=1
# fixing (1,5,2) with x, r2=0.4930953085422516, c=1
# fixing (1,6,0) with 0
# fixing (1,6,1) with x, r2=0.5943388342857361, c=1
# fixing (1,6,2) with x^2, r2=0.9959695339202881, c=2
# fixing (1,7,0) with 0
# fixing (1,7,1) with x, r2=0.9307868480682373, c=1
# fixing (1,7,2) with x, r2=0.00263175368309021, c=1
# fixing (1,8,0) with x, r2=0.9998780488967896, c=1
# fixing (1,8,1) with x, r2=0.9998587369918823, c=1
# fixing (1,8,2) with x, r2=0.9968686103820801, c=1
# saving model version 0.3

# %%
y_pred = dragon_kaam_ihdp.predict(x_test, t_test)
y_pred_0 = y_pred['y_pred_0']
y_pred_1 = y_pred['y_pred_1']
y_pred_f = y_pred['y_pred_f']
ite_pred = y_pred_1 - y_pred_0
mse_kaam_formula = np.mean((y_test - y_pred_f)**2)
pehe_kaam_formula = np.sqrt(np.mean((real_ite_test - y_pred_f)**2))
print(f'MSE KAN formula: {mse_kaam_formula}, PEHE KAN formula: {pehe_kaam_formula}')
print(f'Predicted ATE formula: {ite_pred.mean()}, Real ATE: {real_ite_test.mean()}')
# Out:
# MSE KAN formula: 26.79343985906936, PEHE KAN formula: 4.824187335295197
# Predicted ATE formula: 3.1782314777374268, Real ATE: 3.826578597130422

# %%
# evaluate formula performance

# y_pred = symb_s_kaam.predict(x_test)
# y_pred_0 = y_pred[:, 0]
# y_pred_1 = y_pred[:, 1]
# y_pred_f = t_test * y_pred_1 + (1 - t_test) * y_pred_0
# ite_pred = y_pred_1 - y_pred_0
# mse_formula = np.mean((y_test - y_pred_f)**2)
# pehe_formula = np.sqrt(np.mean((real_ite_test - ite_pred)**2))
# print(f'MSE formula: {mse_formula}, PEHE formula: {pehe_formula}')

# %%
print(formulas)
# Out:
# [-0.5617*x_10 + 0.5772*x_11 + 1.1103*x_12 - 0.2464*x_13 - 0.3154*x_14 + 0.7025*x_15 + 0.6174*x_16 + 0.6059*x_17 + 0.7961*x_18 + 1.2552*x_19 - 0.5493*x_2 + 1.1921*x_21 - 0.0546*x_22 + 0.8908*x_24 - 0.4129*x_25 + 0.1991*x_6 - 0.7544*x_7 - 1.2144*x_8 + 0.3645*x_9 + 0.4992*(0.216*x_10 + 0.1*x_12 + 0.2278*x_14 + 0.5113*x_15 + 0.2005*x_16 + 0.178*x_17 - 0.0616*x_19 + 0.2092*x_21 + 0.2484*x_22 - 0.0734*x_24 + 0.1464*x_25 + 0.3171*x_7 + 0.1775*x_9 - 0.4904*sin(0.5807*x_1 + 2.5804) + 0.2358*sin(0.813*x_2 - 0.7861) + 0.3768*sin(0.6902*x_5 + 5.0122) + 1.6899*sin(0.2259*x_6 - 7.3415) - 0.0981*tan(2.579*x_4 + 6.0114) + 3.3531)*(0.0582*x_1 + 0.1759*x_10 + 0.1813*x_11 + 0.094*x_12 + 0.0844*x_13 + 0.0933*x_14 + 0.5246*x_15 + 0.3394*x_17 + 0.206*x_18 + 0.0636*x_19 + 0.0767*x_22 + 0.3497*x_25 + 0.0207*x_3 + 0.135*x_7 + 0.1345*x_8 + 0.0602*x_9 + 0.0025*(-3.3751*x_6 - 8.9225)**2 - 0.1165*sin(0.7342*x_2 + 8.5555) + 0.5807*sin(0.763*x_5 + 5.3909) - 0.1122*tan(8.605*x_4 - 4.3994) + 1.5381) - 0.0632*(0.1389*x_10 + 0.0797*x_11 + 0.086*x_12 + 0.1479*x_13 - 0.1785*x_14 - 0.0543*x_15 - 0.221*x_17 + 0.1324*x_19 + 0.2115*x_20 - 0.0878*x_21 + 0.3134*x_22 - 0.3056*x_25 - 0.0549*x_5 + 0.2227*x_8 - 0.144*x_9 - 0.0136*(-1.4833*x_1 - 1.9093)**2 - 0.008*(-2.0403*x_6 - 6.9483)**2 - 1.7843*sin(0.2258*x_2 + 5.0249) + 1.0152*sin(0.4289*x_3 - 4.159) - 0.1586*sin(0.6266*x_4 + 8.6025) - 2.4409)*(0.0354*x_10 + 0.1284*x_11 - 0.2233*x_12 + 0.0511*x_13 + 0.3234*x_15 + 0.171*x_17 + 0.1429*x_19 - 0.237*x_20 + 0.1395*x_21 - 0.4657*x_22 - 0.1978*x_23 - 0.1147*x_24 + 0.303*x_25 - 0.2179*x_8 + 0.0568*x_9 + 0.1512*sin(0.7312*x_1 + 5.527) + 1.0483*sin(0.3032*x_2 - 1.1242) + 1.2387*sin(0.4255*x_3 - 7.3753) - 0.539*sin(6.3919*x_4 + 0.9966) - 0.0553*sin(0.9691*x_5 - 3.6332) - 0.8636*sin(0.2871*x_6 - 4.05) + 4.0693) + 0.4105*(0.3392*x_10 + 0.2046*x_11 + 0.0324*x_13 - 0.0791*x_14 + 0.0636*x_15 + 0.3819*x_17 + 0.0621*x_19 + 0.111*x_20 - 0.1926*x_21 + 0.1274*x_22 + 0.0935*x_23 - 0.253*x_24 + 0.4666*x_25 + 0.2314*x_6 + 0.3679*x_7 + 0.5408*x_8 + 0.041*x_9 + 0.4395*exp(0.3339*x_4) + 0.3571*sin(0.739*x_1 - 6.0043) - 0.8144*sin(0.5668*x_2 + 8.5748) + 0.7529*sin(0.3721*x_3 + 1.7928) - 0.6252*sin(0.6106*x_5 + 1.777) + 1.9853)*(0.5146*x_10 + 0.1831*x_11 + 0.1795*x_12 + 0.168*x_13 - 0.0562*x_14 + 0.0576*x_15 + 0.3377*x_17 + 0.2523*x_20 - 0.043*x_21 + 0.1854*x_22 + 0.0538*x_23 - 0.2531*x_24 + 0.4639*x_25 + 0.2815*x_6 + 0.3838*x_7 + 0.4566*x_8 + 0.2365*x_9 - 0.3299*sin(0.9143*x_1 - 2.3866) - 0.7851*sin(0.6322*x_2 + 8.6298) + 0.2542*sin(0.6258*x_3 + 1.7947) - 0.6774*sin(0.6779*x_5 + 8.02) - 0.0634*tan(2.4094*x_4 - 9.4068) + 2.1404) - 0.3655*sin(0.7615*x_1 + 0.3968) - 0.0555*sin(1.0158*x_1 + 1.3745) + 0.0436*sin(1.1498*x_2 + 2.9896) - 1.2845*sin(0.6456*x_3 + 2.2299) - 0.0874*sin(0.9937*x_3 + 0.7898) - 0.6098*sin(6.7636*x_4 + 1.8326) - 0.1891*sin(0.7544*x_5 - 1.4171) - 0.6186*tanh(0.5628*x_5 - 0.3566) - 2.4097, 0.032*x_1 + 0.3332*x_10 - 0.067*x_11 + 0.3293*x_12 + 0.26*x_13 - 0.2055*x_14 - 0.1839*x_15 - 0.0716*x_16 - 0.1*x_17 - 0.0924*x_18 - 0.2922*x_19 + 0.0637*x_2 + 0.072*x_20 - 0.1678*x_21 + 0.2527*x_22 - 0.6116*x_24 + 0.4353*x_25 + 0.0239*x_6 + 0.3879*x_7 + 0.323*x_8 - 0.0106*x_9 - 0.9111*(0.0202*x_2 - 0.1481*x_21 + 0.0418*x_5 - 0.0267*x_6 - 0.1345*sin(0.678*x_3 - 7.5796) - 0.4471)*(0.3337*x_14 + 0.2149*x_21 - 0.6507*x_22 - 0.142*x_5 - 0.2025*x_7 - 0.2691*x_8 + 0.2016*sin(4.5803*x_4 - 2.4094) - 0.1806*tanh(1.0222*x_1 - 0.925) - 0.2402) - 0.2971*(0.3689*x_11 - 0.4167*x_20 + 0.2475*x_21 + 0.3691*x_24 - 0.3129*x_7 + 0.3479*tanh(0.7809*x_5 - 1.0274) + 0.5601)*(-0.1934*x_11 - 0.2308*x_14 - 0.2392*x_21 - 0.404*x_24 + 0.2046*x_7 - 0.1444*sin(0.9677*x_3 + 5.2002) - 0.4907*sin(6.4178*x_4 - 2.1933) - 0.3958*tanh(0.5055*x_5 - 0.7037) - 1.1516) + 0.3037*(0.216*x_10 + 0.1*x_12 + 0.2278*x_14 + 0.5113*x_15 + 0.2005*x_16 + 0.178*x_17 - 0.0616*x_19 + 0.2092*x_21 + 0.2484*x_22 - 0.0734*x_24 + 0.1464*x_25 + 0.3171*x_7 + 0.1775*x_9 - 0.4904*sin(0.5807*x_1 + 2.5804) + 0.2358*sin(0.813*x_2 - 0.7861) + 0.3768*sin(0.6902*x ...

# %%
# extract the CATE
# in this case the CATE is the term that corresponds to the treatment 't'
# Break into additive terms

# Rebuild the expression
cate_formula = formulas[1] - formulas[0]
print(cate_formula)
# Out:
# 0.032*x_1 + 0.8949*x_10 - 0.6442*x_11 - 0.781*x_12 + 0.5064*x_13 + 0.1099*x_14 - 0.8864*x_15 - 0.689*x_16 - 0.7059*x_17 - 0.8885*x_18 - 1.5474*x_19 + 0.613*x_2 + 0.072*x_20 - 1.3599*x_21 + 0.3073*x_22 - 1.502*x_24 + 0.8482*x_25 - 0.1752*x_6 + 1.142*x_7 + 1.5374*x_8 - 0.3751*x_9 - 0.9111*(0.0202*x_2 - 0.1481*x_21 + 0.0418*x_5 - 0.0267*x_6 - 0.1345*sin(0.678*x_3 - 7.5796) - 0.4471)*(0.3337*x_14 + 0.2149*x_21 - 0.6507*x_22 - 0.142*x_5 - 0.2025*x_7 - 0.2691*x_8 + 0.2016*sin(4.5803*x_4 - 2.4094) - 0.1806*tanh(1.0222*x_1 - 0.925) - 0.2402) - 0.2971*(0.3689*x_11 - 0.4167*x_20 + 0.2475*x_21 + 0.3691*x_24 - 0.3129*x_7 + 0.3479*tanh(0.7809*x_5 - 1.0274) + 0.5601)*(-0.1934*x_11 - 0.2308*x_14 - 0.2392*x_21 - 0.404*x_24 + 0.2046*x_7 - 0.1444*sin(0.9677*x_3 + 5.2002) - 0.4907*sin(6.4178*x_4 - 2.1933) - 0.3958*tanh(0.5055*x_5 - 0.7037) - 1.1516) - 0.1955*(0.216*x_10 + 0.1*x_12 + 0.2278*x_14 + 0.5113*x_15 + 0.2005*x_16 + 0.178*x_17 - 0.0616*x_19 + 0.2092*x_21 + 0.2484*x_22 - 0.0734*x_24 + 0.1464*x_25 + 0.3171*x_7 + 0.1775*x_9 - 0.4904*sin(0.5807*x_1 + 2.5804) + 0.2358*sin(0.813*x_2 - 0.7861) + 0.3768*sin(0.6902*x_5 + 5.0122) + 1.6899*sin(0.2259*x_6 - 7.3415) - 0.0981*tan(2.579*x_4 + 6.0114) + 3.3531)*(0.0582*x_1 + 0.1759*x_10 + 0.1813*x_11 + 0.094*x_12 + 0.0844*x_13 + 0.0933*x_14 + 0.5246*x_15 + 0.3394*x_17 + 0.206*x_18 + 0.0636*x_19 + 0.0767*x_22 + 0.3497*x_25 + 0.0207*x_3 + 0.135*x_7 + 0.1345*x_8 + 0.0602*x_9 + 0.0025*(-3.3751*x_6 - 8.9225)**2 - 0.1165*sin(0.7342*x_2 + 8.5555) + 0.5807*sin(0.763*x_5 + 5.3909) - 0.1122*tan(8.605*x_4 - 4.3994) + 1.5381) - 0.0382*(0.1389*x_10 + 0.0797*x_11 + 0.086*x_12 + 0.1479*x_13 - 0.1785*x_14 - 0.0543*x_15 - 0.221*x_17 + 0.1324*x_19 + 0.2115*x_20 - 0.0878*x_21 + 0.3134*x_22 - 0.3056*x_25 - 0.0549*x_5 + 0.2227*x_8 - 0.144*x_9 - 0.0136*(-1.4833*x_1 - 1.9093)**2 - 0.008*(-2.0403*x_6 - 6.9483)**2 - 1.7843*sin(0.2258*x_2 + 5.0249) + 1.0152*sin(0.4289*x_3 - 4.159) - 0.1586*sin(0.6266*x_4 + 8.6025) - 2.4409)*(0.0354*x_10 + 0.1284*x_11 - 0.2233*x_12 + 0.0511*x_13 + 0.3234*x_15 + 0.171*x_17 + 0.1429*x_19 - 0.237*x_20 + 0.1395*x_21 - 0.4657*x_22 - 0.1978*x_23 - 0.1147*x_24 + 0.303*x_25 - 0.2179*x_8 + 0.0568*x_9 + 0.1512*sin(0.7312*x_1 + 5.527) + 1.0483*sin(0.3032*x_2 - 1.1242) + 1.2387*sin(0.4255*x_3 - 7.3753) - 0.539*sin(6.3919*x_4 + 0.9966) - 0.0553*sin(0.9691*x_5 - 3.6332) - 0.8636*sin(0.2871*x_6 - 4.05) + 4.0693) + 0.2032*(0.3392*x_10 + 0.2046*x_11 + 0.0324*x_13 - 0.0791*x_14 + 0.0636*x_15 + 0.3819*x_17 + 0.0621*x_19 + 0.111*x_20 - 0.1926*x_21 + 0.1274*x_22 + 0.0935*x_23 - 0.253*x_24 + 0.4666*x_25 + 0.2314*x_6 + 0.3679*x_7 + 0.5408*x_8 + 0.041*x_9 + 0.4395*exp(0.3339*x_4) + 0.3571*sin(0.739*x_1 - 6.0043) - 0.8144*sin(0.5668*x_2 + 8.5748) + 0.7529*sin(0.3721*x_3 + 1.7928) - 0.6252*sin(0.6106*x_5 + 1.777) + 1.9853)*(0.5146*x_10 + 0.1831*x_11 + 0.1795*x_12 + 0.168*x_13 - 0.0562*x_14 + 0.0576*x_15 + 0.3377*x_17 + 0.2523*x_20 - 0.043*x_21 + 0.1854*x_22 + 0.0538*x_23 - 0.2531*x_24 + 0.4639*x_25 + 0.2815*x_6 + 0.3838*x_7 + 0.4566*x_8 + 0.2365*x_9 - 0.3299*sin(0.9143*x_1 - 2.3866) - 0.7851*sin(0.6322*x_2 + 8.6298) + 0.2542*sin(0.6258*x_3 + 1.7947) - 0.6774*sin(0.6779*x_5 + 8.02) - 0.0634*tan(2.4094*x_4 - 9.4068) + 2.1404) + 0.0525*sin(0.6973*x_1 - 0.313) + 0.4079*sin(0.7615*x_1 + 0.3968) + 0.2063*sin(1.0158*x_1 + 1.3745) + 0.0347*sin(0.84*x_2 - 6.7522) - 0.1621*sin(1.1498*x_2 + 2.9896) - 0.0737*sin(0.6258*x_3 - 3.9798) + 1.4335*sin(0.6456*x_3 + 2.2299) + 0.3251*sin(0.9937*x_3 + 0.7898) - 0.1578*sin(6.4187*x_4 - 5.1852) + 0.6805*sin(6.7636*x_4 + 1.8326) - 0.0979*sin(0.6937*x_5 - 4.3615) - 0.0638*sin(0.6987*x_5 + 1.818) + 0.7033*sin(0.7544*x_5 - 1.4171) + 0.0162*tan(9.5876*x_4 - 8.2034) + 0.6904*tanh(0.5628*x_5 - 0.3566) + 3.791

# %%
# ite_pred_formula = eval_expr_on_df(cate_formula, data_test)
# pehe_formula_cate = np.sqrt(np.mean((real_ite_test - ite_pred_formula)**2))
# print(f'PEHE formula cate: {pehe_formula_cate}')

# %%
# chage x1, x2, x3... by x_1, x_2,...
x_cols_ = ['x_' + col[1:] for col in x_cols]
test_df = pd.DataFrame(data_test.loc[:, x_cols].to_numpy(), columns=x_cols_)

# %%
ite_pred_formula = get_formula_values(cate_formula, test_df.copy())
print(ite_pred_formula)
# Out:
# 100%|██████████| 224/224 [00:46<00:00,  4.77it/s]
# [[ 9.72983867e-02]
#  [-1.91365111e+00]
#  [ 2.99473763e+00]
#  [ 1.06877843e+00]
#  [ 5.02938050e+00]
#  [ 6.56110193e+00]
#  [ 4.75688639e+00]
#  [-1.23992864e+00]
#  [ 2.42613228e+00]
#  [ 4.13071561e+00]
#  [ 4.81018821e+00]
#  [-3.23527895e+00]
#  [ 2.56129162e+00]
#  [ 6.73980826e+00]
#  [ 4.94533489e+00]
#  [ 1.93772022e+00]
#  [ 2.25781061e+00]
#  [ 5.74183932e+00]
#  [ 9.87932155e-01]
#  [ 3.20204488e+00]
#  [ 2.67093152e+00]
#  [ 6.10581850e-01]
#  [-3.03539825e+00]
#  [ 5.06167721e+00]
#  [ 7.02844022e-01]
#  [ 7.00658813e+00]
#  [ 2.70997050e+00]
#  [ 4.80829376e+00]
#  [ 5.58252341e+00]
#  [ 1.80809406e+00]
#  [ 5.01951759e+00]
#  [ 4.11107823e+00]
#  [ 2.51142856e+00]
#  [ 1.27612918e+00]
#  [-8.73479084e-01]
#  [ 6.26881357e+00]
#  [ 4.49327239e+00]
#  [ 1.69859359e+00]
#  [ 4.64637516e+00]
#  [ 2.00401410e+00]
#  [ 3.42353211e+00]
#  [-1.42810966e-01]
#  [ 6.73149789e+00]
#  [ 4.06682599e+00]
#  [ 7.29918762e+00]
#  [ 4.61827679e+00]
#  [ 7.99410950e+00]
#  [ 5.10866758e+00]
#  [ 3.32340916e+00]
#  [ 5.99032871e+00]
#  [ 3.89804280e+00]
#  [ 7.61770243e+00]
#  [ 6.59874019e+00]
#  [ 3.29244140e+00]
#  [ 2.44160235e+00]
#  [ 4.36939047e+00]
#  [ 4.53628282e+00]
#  [ 5.39315393e+00]
#  [ 5.57507677e+00]
#  [ 3.90048947e+00]
#  [ 2.64092409e+00]
#  [ 1.66639321e+00]
#  [ 1.15205435e+00]
#  [ 4.68510536e+00]
#  [ 2.07133603e+00]
#  [ 2.51784813e+00]
#  [ 1.53797349e+00]
#  [ 3.56598948e+00]
#  [ 2.12869254e+00]
#  [ 6.05962852e-01]
#  [ 4.61177361e-03]
#  [ 3.34329165e+00]
#  [ 5.95005422e-01]
#  [ 3.77873088e+00]
#  [ 6.25520132e+00]
#  [ 4.96334813e-01]
#  [ 3.33542382e+00]
#  [ 3.03469126e+00]
#  [ 4.08936754e+00]
#  [ 6.52384958e-01]
#  [ 3.20147579e+00]
#  [ 2.06690092e+00]
#  [ 6.90870003e+00]
#  [ 3.68976718e+00]
#  [ 3.24919141e+00]
#  [ 7.35450025e-01]
#  [-2.18674668e+00]
#  [ 5.57073397e-01]
#  [-1.50612907e+00]
#  [ 2.61344430e+00]
#  [ 1.87808814e+00]
#  [ 6.00309621e+00]
#  [ 3.69442847e+00]
#  [-3.88209954e+00]
#  [ 2.11948221e+00]
#  [ 4.33669766e-01]
#  [ 2.25484268e+00]
#  [ 3.33652104e+00]
#  [-6.24514275e-01]
#  [ 5.14959975e+00]
#  [ 4.02634620e+00]
#  [ 7.87093185e-01]
#  [ 6.50407787e-01]
#  [ 6.42816907e+00]
#  [ 5.26318330e+00]
#  [ 1.94395072e+00]
#  [ 1.83028011e+00]
#  [ 3.02603813e+00]
#  [ 7.01041437e+00]
#  [ 5.58679412e+00]
#  [ 8.11280556e-01]
#  [ 6.98094661e+00]
#  [ 5.15275467e+00]
#  [ 2.93879540e+00]
#  [ 6.58752882e+00]
#  [ 4.06107152e+00]
#  [ 2.52915663e+00]
#  [ 1.50319571e+00]
#  [-2.12063433e+00]
#  [ 2.95637085e+00]
#  [ 5.12979092e+00]
#  [ 5.69490729e+00]
#  [ 6.29575241e+00]
#  [ 2.18331796e-01]
#  [ 1.58524710e+00]
#  [ 3.84139585e+00]
#  [ 1.00243033e+00]
#  [ 2.88489153e+00]
#  [ 7.32912154e-02]
#  [ 6.61961686e+00]
#  [ 4.41438628e+00]
#  [ 4.65111256e+00]
#  [ 4.30859587e+00]
#  [ 4.31273761e+00]
#  [ 1.61594492e+00]
#  [ 8.22323602e-01]
#  [ 1.23092395e+00]
#  [-1.14353373e+00]
#  [ 1.02437444e+00]
#  [ 2.76974276e+00]
#  [ 2.29505566e+00]
#  [ 1.87854893e+00]
#  [ 4.90993017e+00]
#  [ 2.93891949e+00]
#  [ 5.27241502e+00]
#  [ 4.57201503e+00]
#  [ 1.22355862e+00]
#  [ 2.05589191e+00]
#  [ 3.97421998e+00]
#  [ 4.55970787e+00]
#  [ 4.31159366e+00]
#  [ 3.67968994e+00]
#  [ 5.38141690e+00]
#  [ 3.37330093e+00]
#  [-1.88261925e+00]
#  [-4.12351328e+00]
#  [ 2.09786236e+00]
#  [ 3.58006167e+00]
#  [ 1.19943422e+00]
#  [ 3.88881760e+00]
#  [ 2.16989754e+00]
#  [ 1.06384819e+00]
#  [ 5.36184387e+00]
#  [-7.33646609e-01]
#  [-3.29983513e-01]
#  [ 2.58797289e+00]
#  [ 1.55821456e+00]
#  [ 5.03897755e-01]
#  [ 2.97951572e+00]
#  [ 4.00461645e+00]
#  [ 3.39483523e+00]
#  [ 4.34862224e+00]
#  [-2.24921883e+00]
#  [ 6.89126863e+00]
#  [ 3.57525649e+00]
#  [ 3.21340345e+00]
#  [ 5.37432541e+00]
#  [ 7.71978674e+00]
#  [ 6.06072697e+00]
#  [ 3.68158601e+00]
#  [ 3.66340206e+00]
#  [ 5.09179142e+00]
#  [ 4.54402661e+00]
#  [-2.10035956e+00]
#  [ 5.96731165e+00]
#  [ 6.84042725e+00]
#  [ 4.59247791e+00]
#  [ 5.82438373e+00]
#  [ 5.43117673e+00]
#  [ 5.87343547e+00]
#  [ 3.04074183e+00]
#  [ 1.00337396e+01]
#  [ 4.58380536e+00]
#  [ 3.73913139e+00]
#  [ 6.11146971e+00]
#  [ 4.18288965e+00]
#  [ 4.48439635e+00]
#  [ 3.69884132e+00]
#  [ 9.28927063e-01]
#  [ 2.57572301e+00]
#  [ 3.81258199e+00]
#  [ 3.29647524e+00]
#  [ 5.09859265e+00]
#  [ 5.45172260e+00]
#  [ 6.72539507e+00]
#  [ 4.43634088e+00]
#  [ 1.89764245e+00]
#  [ 2.79684918e+00]
#  [ 4.16689809e-01]
#  [ 2.90267715e+00]
#  [ 1.90981480e+00]
#  [ 4.78238613e+00]
#  [ 4.16372787e+00]
#  [ 5.79400891e+00]
#  [ 6.72783254e+00]
#  [-1.35092904e-01]
#  [-2.47013589e+00]
#  [ 3.55029852e+00]
#  [ 4.21814227e+00]
#  [ 3.47241730e+00]
#  [ 3.02388220e+00]
#  [ 5.92364238e+00]
#  [ 2.58837771e+00]
#  [ 4.32956666e+00]]

# %%
pehe_formula_cate = np.sqrt(np.mean((real_ite_test - ite_pred_formula)**2))
print(f'PEHE formula cate: {pehe_formula_cate}')
# Out:
# PEHE formula cate: 4.296792070654834

# %%
# formula_0_rounded = sp.sympify(sp.nsimplify(formulas[0], tolerance=1e-2))
# y_pred_0_trunc = eval_expr_on_df(formula_0_rounded, data_test)
# formula_1_rounded = sp.sympify(sp.nsimplify(formulas[0], tolerance=1e-2))
# y_pred_1_trunc = eval_expr_on_df(formula_1_rounded, data_test)
# y_pred_f_trunc = y_pred_0_trunc * (1 - t_test[:,0]) + y_pred_1_trunc * t_test[:,0]
# ite_pred_trunc = y_pred_1_trunc - y_pred_0_trunc
# mse_formula_trunc = np.mean((y_test[:,0] - y_pred_f_trunc)**2)
# pehe_formula_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_trunc)**2))
# print(f'MSE formula truncated: {mse_formula_trunc}, PEHE formula truncated: {pehe_formula_trunc}')

# %%
# truncate
formulas_trun = [ex_round(f, 2) for f in formulas]
y_pred_0_trunc = get_formula_values(formulas_trun[0], test_df.copy())
y_pred_1_trunc = get_formula_values(formulas_trun[1],  test_df.copy())
y_pred_f_trunc = y_pred_0_trunc * (1 - t_test[:,0]) + y_pred_1_trunc * t_test[:,0]
ite_pred_trunc = y_pred_1_trunc - y_pred_0_trunc
mse_formula_trunc = np.mean((y_test[:,0] - y_pred_f_trunc)**2)
pehe_formula_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_trunc)**2))
print(f'MSE formula truncated: {mse_formula_trunc}, PEHE formula truncated: {pehe_formula_trunc}')
print(f'Predicted ATE formula truncated: {ite_pred_trunc.mean()}, Real ATE: {real_ite_test.mean()}')
# Out:
# 100%|██████████| 224/224 [00:29<00:00,  7.56it/s]
# 100%|██████████| 224/224 [00:35<00:00,  6.37it/s]
# MSE formula truncated: 27.404776595898653, PEHE formula truncated: 4.2694041498261885
# Predicted ATE formula truncated: 3.2396191189480406, Real ATE: 3.826578597130422

# %%
# #print pehe with cate formula truncated
# cate_formula_trunc = formulas_1_rounded - formulas_0_rounded
# ite_pred_formula_trunc = eval_expr_on_df(cate_formula_trunc, data_test)
# pehe_formula_cate_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_formula_trunc)**2))
# print(f'PEHE formula cate truncated: {pehe_formula_cate_trunc}')

# %%
#print pehe with cate formula truncated
cate_formula_trunc = formulas_trun[1] - formulas_trun[0]
ite_pred_formula_trunc = get_formula_values(cate_formula_trunc, test_df.copy())
pehe_formula_cate_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_formula_trunc)**2))
print(f'PEHE formula cate truncated: {pehe_formula_cate_trunc}')
print(f'ATE formula cate truncated: {ite_pred_formula_trunc.mean()}, Real ATE: {real_ite_test.mean()}')
# Out:
# 100%|██████████| 224/224 [00:33<00:00,  6.62it/s]
# PEHE formula cate truncated: 4.269112252741745
# ATE formula cate truncated: 3.240369020285241, Real ATE: 3.826578597130422

# %%
present = {s.name for s in formulas[0].free_symbols}
print(present)
# Out:
# {'x_21', 'x_4', 'x_14', 'x_22', 'x_15', 'x_20', 'x_6', 'x_3', 'x_23', 'x_17', 'x_12', 'x_13', 'x_16', 'x_10', 'x_9', 'x_8', 'x_2', 'x_11', 'x_19', 'x_1', 'x_18', 'x_24', 'x_7', 'x_5', 'x_25'}

# %%
ausent = set(x_cols) - present
print(ausent)
# Out:
# {'x6', 'x4', 'x7', 'x8', 'x15', 'x9', 'x20', 'x11', 'x21', 'x1', 'x10', 'x5', 'x17', 'x23', 'x25', 'x2', 'x13', 'x22', 'x19', 'x3', 'x18', 'x24', 'x14', 'x16', 'x12'}

# %%
n_feats = len(list(present))

# %% [markdown]
# # ACIC 2

# %%
#load the data
i = 3
split = 0.2

data_train, data_test = load_data('ACIC_2', i)
col_names = data_train.columns
x_cols = [col for col in data_train.columns if 'x' in col]

x_train, y_train, t_train = data_train[x_cols].values, data_train['y_factual'].values[:, None], data_train[
                                                                                                    'treatment'].values[
                                                                                                :, None]
x_test, y_test, t_test = data_test[[col for col in data_test.columns if 'x' in col]].values, data_test[
                                                                                                 'y_factual'].values[:,
                                                                                             None], data_test[
                                                                                                        'treatment'].values[
                                                                                                    :, None]

x_train, x_val, y_train, y_val, t_train, t_val = train_test_split(x_train, y_train, t_train, test_size=split,
                                                                  shuffle=False)

real_ite_train = data_train['mu1'].values - data_train['mu0'].values
real_ite_test = data_test['mu1'].values - data_test['mu0'].values

real_ite_train, real_ite_val = real_ite_train[:x_train.shape[0]], real_ite_train[x_train.shape[0]:]
print(col_names)
print(x_cols)

data_test_t0 = data_test.copy()
data_test_t0['treatment'] = 0
data_test_t1 = data_test.copy()
data_test_t1['treatment'] = 1
# preprocess the data
print(x_train.shape, y_train.shape, t_train.shape, x_val.shape, y_val.shape, t_val.shape, x_test.shape, y_test.shape,
      t_test.shape, real_ite_train.shape, real_ite_test.shape, real_ite_val.shape)
# instanciate the KAN model
# T-KAAM
width = get_width('dragonnet', x_train.shape[1], hidden_dims=[5], mult_kan=True)
dragon_kaam = kan_net('dragonnet', width, grid=3, k=3, sparse_init=False, try_gpu=False, real_ite_train=real_ite_train,
                      real_ite_test=real_ite_val, save_folder='visualization/checkpoint')
#train the model
tic = time.time()
results = dragon_kaam.fit(x_train, y_train, t_train, x_val, y_val, t_val, early_stop=True, patience=30, batch=1000,
                          steps=10000, lamb=0.01, lamb_entropy=0.1, lr=0.001, verbose=0)
tac = time.time()
print(results.keys())
print('Training time: ', tac - tic)
prediction = dragon_kaam.predict(x_test, t_test)
print(prediction.keys())
prediction['ite'] = prediction['y_pred_1'] - prediction['y_pred_0']
# Compute prediction metrics in MSE of factual outcome and
mse = np.mean((y_test - prediction['y_pred_f']) ** 2)
pehe = np.sqrt(np.mean((real_ite_test - prediction['ite']) ** 2))
print(f'MSE original KAN: {mse}, PEHE original KAN: {pehe}')
print(f'Predicted ATE: {prediction["ite"].mean()}, Real ATE: {real_ite_test.mean()}')
# MLP params = hidden_dims= [100, 100, 100], dropout=0.0, lr=1e-05, activation=leaky_relu
dims_mlp = get_dims_mlp('dragonnet', x_train.shape[1], hidden_dims=[[200, 200, 200], [100, 100], []])
dragon_nn = mlp_net('dragonnet', dims_mlp, dropout=0.0, activation='elu', try_gpu=False,
                    save_folder='visualization/checkpoint', real_ite_train=real_ite_train, real_ite_test=real_ite_val)
tic = time.time()
results_mlp = dragon_nn.fit(x_train, y_train, t_train, x_val, y_val, t_val, early_stop=True, patience=30, batch=1000,
                            steps=10000, lr=1e-5, verbose=0)
tac = time.time()
print(results_mlp.keys())
print('Training time MLP: ', tac - tic)

prediction_mlp = dragon_nn.predict(x_test, t_test)
prediction_mlp['ite'] = prediction_mlp['y_pred_1'] - prediction_mlp['y_pred_0']
mse_mlp = np.mean((y_test - prediction_mlp['y_pred_f']) ** 2)
pehe_mlp = np.sqrt(np.mean((real_ite_test - prediction_mlp['ite']) ** 2))
print(f'MSE MLP: {mse_mlp}, PEHE MLP: {pehe_mlp}')
print(f'ATE MLP: {prediction_mlp["ite"].mean()}, Real ATE: {real_ite_test.mean()}')
print(results.keys())
# formula without pruning
# symb_s_kaam_orig = symbolic_kan_regressor(x_names=x_cols, y_names=['mu_0', 'mu_1', 'propensity'])
# with plt.rc_context({**bundles.iclr2024()}):
#     tic = time.time()
#     xt_train = np.concatenate((x_train, t_train), axis=1)
#     xt_val = np.concatenate((x_val, t_val), axis=1)
#     # out_0 = symb_s_kaam_orig.fit(dragon_kaam.model, xt_train, y_train, xt_val, y_val, denorm_function=None, stochastic=False, r2_threshold=0.98, show_results=False, save_dir = 'visualization/formulas')
#     out_0 = symb_s_kaam_orig.fit(dragon_kaam.model, x_train, y_train, x_val, y_val, denorm_function=None,
#                                  stochastic=False, r2_threshold=0.98, show_results=False,
#                                  save_dir='visualization/formulas')
#     tac = time.time()
#     print('Formula extraction time (control): ', tac - tic)
#
# formulas_orig = symb_s_kaam_orig.get_formula()
# print(formulas_orig[0])
# print(formulas_orig[0])
# PRUNING AND FORMULA EXTRACTION
# pruning and evaluation
# t_kaam_original = copy.deepcopy(t_kaam)
tic = time.time()
dragon_kaam_pruned = dragon_kaam.prune(node_th=1e-2, edge_th=1e-2)
tac = time.time()
print('Pruning time: ', tac - tic)
#evaluate
predictions_pruned = dragon_kaam.predict(x_test, t_test)
predictions_pruned['ite'] = predictions_pruned['y_pred_1'] - predictions_pruned['y_pred_0']
mse_pruned = np.mean((y_test - predictions_pruned['y_pred_f']) ** 2)
pehe_pruned = np.sqrt(np.mean((real_ite_test - predictions_pruned['ite']) ** 2))
print(f'MSE pruned KAN: {mse_pruned}, PEHE pruned KAN: {pehe_pruned}')
print(f'Predicted ATE: {predictions_pruned["ite"].mean()}, Real ATE: {real_ite_test.mean()}')
# # formula extraction
# symb_s_kaam = symbolic_kan_regressor(x_names = x_cols, y_names=['mu_0', 'mu_1', 'propensity'])
# with plt.rc_context({**bundles.iclr2024()}):
#     tic = time.time()
#     xt_train = np.concatenate((x_train, t_train), axis=1)
#     xt_val = np.concatenate((x_val, t_val), axis=1)
#     # out_0 = symb_s_kaam.fit(dragon_kaam.model, xt_train, y_train, xt_val, y_val, denorm_function=None, stochastic=False, r2_threshold=0.98, show_results=False, save_dir = 'visualization/formulas')
#     out_0 = symb_s_kaam.fit(dragon_kaam.model, x_train, y_train, x_val, y_val, denorm_function=None, stochastic=False, r2_threshold=0.98, show_results=False, save_dir = 'visualization/formulas')
#     tac = time.time()
#     print('Formula extraction time (control): ', tac - tic)
# formulas = symb_s_kaam.get_formula()
# Out:
# Index(['treatment', 'y_factual', 'y_cfactual', 'mu0', 'mu1', 'x1', 'x2', 'x3',
#        'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14',
#        'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24',
#        'x25', 'x26', 'x27', 'x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34',
#        'x35', 'x36', 'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44',
#        'x45', 'x46', 'x47', 'x48', 'x49', 'x50', 'x51', 'x52', 'x53', 'x54',
#        'x55', 'x56', 'x57', 'x58'],
#       dtype='object')
# ['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26', 'x27', 'x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49', 'x50', 'x51', 'x52', 'x53', 'x54', 'x55', 'x56', 'x57', 'x58']
# (800, 58) (800, 1) (800, 1) (200, 58) (200, 1) (200, 1) (960, 58) (960, 1) (960, 1) (800,) (960,) (200,)
# checkpoint directory created: C:\Users\Alex\CODE\causalkans\visualization/checkpoint\kan_345353\
# saving model version 0.0
# Early stopping at step 559
# saving model version 0.1
# dict_keys(['train_loss', 'test_loss', 'reg', 'train_metrics', 'test_metrics'])
# Training time:  33.753222942352295
# dict_keys(['y_pred_0', 'y_pred_1', 'y_pred_f', 'y_pred_cf', 'ps_pred', 'pred_best_treatment'])
# MSE original KAN: 11.197496541253416, PEHE original KAN: 2.5439611491445167
# Predicted ATE: 4.511167526245117, Real ATE: 4.229490757544409
# Early stopping at step 1210
# dict_keys(['train_loss', 'test_loss', 'reg', 'train_metrics', 'test_metrics'])
# Training time MLP:  24.595968008041382
# MSE MLP: 8.317522484563396, PEHE MLP: 1.3506746055696555
# ATE MLP: 4.492605686187744, Real ATE: 4.229490757544409
# dict_keys(['train_loss', 'test_loss', 'reg', 'train_metrics', 'test_metrics'])
# saving model version 0.2
# Pruning time:  0.11069822311401367
# MSE pruned KAN: 9.689694255523069, PEHE pruned KAN: 2.6973816145007725
# Predicted ATE: 2.120824098587036, Real ATE: 4.229490757544409

# %%
formulas = dragon_kaam.interprete('all', n_digit=4)
# Out:
# Using library all
# fixing (0,0,0) with x, r2=0.06568443775177002, c=1
# fixing (0,0,1) with sin, r2=0.9997977018356323, c=2
# fixing (0,0,2) with 0
# fixing (0,0,3) with 0
# fixing (0,0,4) with x^2, r2=0.9998084902763367, c=2
# fixing (0,0,5) with 0
# fixing (0,0,6) with 0
# fixing (0,0,7) with x, r2=0.19280271232128143, c=1
# fixing (0,0,8) with tanh, r2=0.9998217225074768, c=3
# fixing (0,0,9) with x, r2=0.7966095805168152, c=1
# fixing (0,0,10) with 0
# fixing (0,0,11) with x^2, r2=0.9751867055892944, c=2
# fixing (0,0,12) with x, r2=0.37401631474494934, c=1
# fixing (0,0,13) with x, r2=0.07438771426677704, c=1
# fixing (0,0,14) with x, r2=0.4498281478881836, c=1
# fixing (0,1,0) with 0
# fixing (0,1,1) with 0
# fixing (0,1,2) with 0
# fixing (0,1,3) with 0
# fixing (0,1,4) with 0
# fixing (0,1,5) with 0
# fixing (0,1,6) with x, r2=1.000001072883606, c=1
# fixing (0,1,7) with 0
# fixing (0,1,8) with 0
# fixing (0,1,9) with 0
# fixing (0,1,10) with x, r2=1.000001072883606, c=1
# fixing (0,1,11) with x, r2=1.0000020265579224, c=1
# fixing (0,1,12) with 0
# fixing (0,1,13) with 0
# fixing (0,1,14) with 0
# fixing (0,2,0) with 0
# fixing (0,2,1) with 0
# fixing (0,2,2) with 0
# fixing (0,2,3) with 0
# fixing (0,2,4) with 0
# fixing (0,2,5) with 0
# fixing (0,2,6) with 0
# fixing (0,2,7) with 0
# fixing (0,2,8) with 0
# fixing (0,2,9) with 0
# fixing (0,2,10) with sin, r2=0.9983384609222412, c=2
# fixing (0,2,11) with sin, r2=0.9996811151504517, c=2
# fixing (0,2,12) with 0
# fixing (0,2,13) with sin, r2=0.9978933930397034, c=2
# fixing (0,2,14) with 0
# fixing (0,3,0) with sin, r2=0.9993494749069214, c=2
# fixing (0,3,1) with 0
# fixing (0,3,2) with 0
# fixing (0,3,3) with 0
# fixing (0,3,4) with sin, r2=0.9995990991592407, c=2
# fixing (0,3,5) with 0
# fixing (0,3,6) with sin, r2=0.9994836449623108, c=2
# fixing (0,3,7) with x, r2=0.7369484305381775, c=1
# fixing (0,3,8) with x, r2=0.22966498136520386, c=1
# fixing (0,3,9) with 0
# fixing (0,3,10) with sin, r2=0.998100221157074, c=2
# fixing (0,3,11) with x, r2=0.11430180817842484, c=1
# fixing (0,3,12) with x, r2=0.4252091646194458, c=1
# fixing (0,3,13) with x, r2=0.9864898920059204, c=1
# fixing (0,3,14) with x, r2=0.9893951416015625, c=1
# fixing (0,4,0) with 0
# fixing (0,4,1) with 0
# fixing (0,4,2) with 0
# fixing (0,4,3) with 0
# fixing (0,4,4) with x, r2=0.7363807559013367, c=1
# fixing (0,4,5) with sin, r2=0.9861494302749634, c=2
# fixing (0,4,6) with 0
# fixing (0,4,7) with sin, r2=0.9903870224952698, c=2
# fixing (0,4,8) with x, r2=0.6293478012084961, c=1
# fixing (0,4,9) with x, r2=0.78737473487854, c=1
# fixing (0,4,10) with x, r2=0.7520370483398438, c=1
# fixing (0,4,11) with 0
# fixing (0,4,12) with sin, r2=0.9753690958023071, c=2
# fixing (0,4,13) with 0
# fixing (0,4,14) with x, r2=0.52897047996521, c=1
# fixing (0,5,0) with 0
# fixing (0,5,1) with 0
# fixing (0,5,2) with 0
# fixing (0,5,3) with 0
# fixing (0,5,4) with sin, r2=0.9993915557861328, c=2
# fixing (0,5,5) with x, r2=0.921483039855957, c=1
# fixing (0,5,6) with 0
# fixing (0,5,7) with x, r2=0.7546659708023071, c=1
# fixing (0,5,8) with x, r2=0.9903197288513184, c=1
# fixing (0,5,9) with sin, r2=0.9968950152397156, c=2
# fixing (0,5,10) with sin, r2=0.9975714683532715, c=2
# fixing (0,5,11) with x, r2=0.5718660950660706, c=1
# fixing (0,5,12) with x, r2=0.7602809071540833, c=1
# fixing (0,5,13) with sin, r2=0.993860125541687, c=2
# fixing (0,5,14) with 0
# fixing (0,6,0) with 0
# fixing (0,6,1) with 0
# fixing (0,6,2) with 0
# fixing (0,6,3) with 0
# fixing (0,6,4) with 0
# fixing (0,6,5) with x, r2=0.9988751411437988, c=1
# fixing (0,6,6) with 0
# fixing (0,6,7) with sin, r2=0.9998173117637634, c=2
# fixing (0,6,8) with sin, r2=0.9997403025627136, c=2
# fixing (0,6,9) with sin, r2=0.9998276233673096, c=2
# fixing (0,6,10) with x, r2=0.9993202090263367, c=1
# fixing (0,6,11) with sin, r2=0.9995752573013306, c=2
# fixing (0,6,12) with exp, r2=0.9997270703315735, c=2
# fixing (0,6,13) with x, r2=0.9980331063270569, c=1
# fixing (0,6,14) with 0
# fixing (0,7,0) with 0
# fixing (0,7,1) with 0
# fixing (0,7,2) with 0
# fixing (0,7,3) with 0
# fixing (0,7,4) with 0
# fixing (0,7,5) with sin, r2=0.999999463558197, c=2
# fixing (0,7,6) with 0
# fixing (0,7,7) with sin, r2=1.0000003576278687, c=2
# fixing (0,7,8) with sin, r2=1.000000238418579, c=2
# fixing (0,7,9) with sin, r2=0.9999983310699463, c=2
# fixing (0,7,10) with 0
# fixing (0,7,11) with 0
# fixing (0,7,12) with 0
# fixing (0,7,13) with sin, r2=0.9999990463256836, c=2
# fixing (0,7,14) with sin, r2=0.9999998211860657, c=2
# fixing (0,8,0) with sin, r2=1.0000004768371582, c=2
# fixing (0,8,1) with 0
# fixing (0,8,2) with 0
# fixing (0,8,3) with 0
# fixing (0,8,4) with sin, r2=1.000000238418579, c=2
# fixing (0,8,5) with sin, r2=1.0000004768371582, c=2
# fixing (0,8,6) with sin, r2=1.0000004768371582, c=2
# fixing (0,8,7) with sin, r2=1.0000004768371582, c=2
# fixing (0,8,8) with x, r2=0.9991558790206909, c=1
# fixing (0,8,9) with sin, r2=1.0000004768371582, c=2
# fixing (0,8,10) with sin, r2=1.0000004768371582, c=2
# fixing (0,8,11) with sin, r2=1.000000238418579, c=2
# fixing (0,8,12) with sin, r2=0.9999875426292419, c=2
# fixing (0,8,13) with sin, r2=1.0000003576278687, c=2
# fixing (0,8,14) with sin, r2=1.0000004768371582, c=2
# fixing (0,9,0) with sin, r2=0.9999388456344604, c=2
# fixing (0,9,1) with 0
# fixing (0,9,2) with 0
# fixing (0,9,3) with 0
# fixing (0,9,4) with 0
# fixing (0,9,5) with 0
# fixing (0,9,6) with sin, r2=0.9999448657035828, c=2
# fixing (0,9,7) with sin, r2=0.9998027086257935, c=2
# fixing (0,9,8) with sin, r2=0.9996283650398254, c=2
# fixing (0,9,9) with 0
# fixing (0,9,10) with sin, r2=0.9999433159828186, c=2
# fixing (0,9,11) with sin, r2=0.9999431371688843, c=2
# fixing (0,9,12) with sin, r2=0.9999534487724304, c=2
# fixing (0,9,13) with sin, r2=0.999950110912323, c=2
# fixing (0,9,14) with 0
# fixing (0,10,0) with 0
# fixing (0,10,1) with 0
# fixing (0,10,2) with 0
# fixing (0,10,3) with 0
# fixing (0,10,4) with 0
# fixing (0,10,5) with 0
# fixing (0,10,6) with 0
# fixing (0,10,7) with x, r2=1.0000009536743164, c=1
# fixing (0,10,8) with 0
# fixing (0,10,9) with 0
# fixing (0,10,10) with 0
# fixing (0,10,11) with x, r2=1.0000014305114746, c=1
# fixing (0,10,12) with 0
# fixing (0,10,13) with 0
# fixing (0,10,14) with 0
# fixing (0,11,0) with 0
# fixing (0,11,1) with 0
# fixing (0,11,2) with 0
# fixing (0,11,3) with 0
# fixing (0,11,4) with 0
# fixing (0,11,5) with sin, r2=0.9997712969779968, c=2
# fixing (0,11,6) with sin, r2=0.9997035264968872, c=2
# fixing (0,11,7) with sin, r2=0.9989534020423889, c=2
# fixing (0,11,8) with sin, r2=0.9997201561927795, c=2
# fixing (0,11,9) with sin, r2=0.999552309513092, c=2
# fixing (0,11,10) with sin, r2=0.9997225403785706, c=2
# fixing (0,11,11) with sin, r2=0.9996570348739624, c=2
# fixing (0,11,12) with sin, r2=0.9997172355651855, c=2
# fixing (0,11,13) with sin, r2=0.9997335076332092, c=2
# fixing (0,11,14) with sin, r2=0.9997156858444214, c=2
# fixing (0,12,0) with sin, r2=0.9995319843292236, c=2
# fixing (0,12,1) with sin, r2=0.9995246529579163, c=2
# fixing (0,12,2) with 0
# fixing (0,12,3) with 0
# fixing (0,12,4) with 0
# fixing (0,12,5) with sin, r2=0.9994919300079346, c=2
# fixing (0,12,6) with sin, r2=0.9994472861289978, c=2
# fixing (0,12,7) with sin, r2=0.9984099864959717, c=2
# fixing (0,12,8) with sin, r2=0.9974049925804138, c=2
# fixing (0,12,9) with 0
# fixing (0,12,10) with 0
# fixing (0,12,11) with sin, r2=0.999682605266571, c=2
# fixing (0,12,12) with 0
# fixing (0,12,13) with sin, r2=0.999508798122406, c=2
# fixing (0,12,14) with sin, r2=0.9994663596153259, c=2
# fixing (0,13,0) with 0
# fixing (0,13,1) with sin, r2=1.0000005960464478, c=2
# fixing (0,13,2) with 0
# fixing (0,13,3) with 0
# fixing (0,13,4) with 0
# fixing (0,13,5) with sin, r2=0.9999980330467224, c=2
# fixing (0,13,6) with 0
# fixing (0,13,7) with sin, r2=0.9999973773956299, c=2
# fixing (0,13,8) with sin, r2=0.9999993443489075, c=2
# fixing (0,13,9) with sin, r2=1.000000238418579, c=2
# fixing (0,13,10) with exp, r2=0.9999971389770508, c=2
# fixing (0,13,11) with sin, r2=0.9999929070472717, c=2
# fixing (0,13,12) with sin, r2=0.9999996423721313, c=2
# fixing (0,13,13) with sin, r2=0.9999994039535522, c=2
# fixing (0,13,14) with sin, r2=0.9999994039535522, c=2
# fixing (0,14,0) with 0
# fixing (0,14,1) with 0
# fixing (0,14,2) with sin, r2=0.9998108148574829, c=2
# fixing (0,14,3) with 0
# fixing (0,14,4) with 0
# fixing (0,14,5) with sin, r2=0.9997978806495667, c=2
# fixing (0,14,6) with 0
# fixing (0,14,7) with sin, r2=0.999900221824646, c=2
# fixing (0,14,8) with sin, r2=0.9998791217803955, c=2
# fixing (0,14,9) with sin, r2=0.9999601244926453, c=2
# fixing (0,14,10) with sin, r2=0.9997959136962891, c=2
# fixing (0,14,11) with sin, r2=0.9996598362922668, c=2
# fixing (0,14,12) with exp, r2=0.9999386072158813, c=2
# fixing (0,14,13) with 0
# fixing (0,14,14) with sin, r2=0.9992197155952454, c=2
# fixing (0,15,0) with 0
# fixing (0,15,1) with 0
# fixing (0,15,2) with 0
# fixing (0,15,3) with 0
# fixing (0,15,4) with x^2, r2=1.0000007152557373, c=2
# fixing (0,15,5) with x^2, r2=1.0000007152557373, c=2
# fixing (0,15,6) with x^2, r2=1.0000008344650269, c=2
# fixing (0,15,7) with x^2, r2=1.0000008344650269, c=2
# fixing (0,15,8) with x^2, r2=1.0000009536743164, c=2
# fixing (0,15,9) with 0
# fixing (0,15,10) with x^2, r2=1.0000008344650269, c=2
# fixing (0,15,11) with x^2, r2=1.0000008344650269, c=2
# fixing (0,15,12) with 0
# fixing (0,15,13) with x^2, r2=1.0000009536743164, c=2
# fixing (0,15,14) with x^2, r2=1.0000008344650269, c=2
# fixing (0,16,0) with 0
# fixing (0,16,1) with 0
# fixing (0,16,2) with 0
# fixing (0,16,3) with 0
# fixing (0,16,4) with 0
# fixing (0,16,5) with 0
# fixing (0,16,6) with 0
# fixing (0,16,7) with x, r2=1.0000008344650269, c=1
# fixing (0,16,8) with 0
# fixing (0,16,9) with x, r2=1.0000005960464478, c=1
# fixing (0,16,10) with x, r2=1.0000007152557373, c=1
# fixing (0,16,11) with x, r2=1.0000009536743164, c=1
# fixing (0,16,12) with x, r2=1.0000008344650269, c=1
# fixing (0,16,13) with 0
# fixing (0,16,14) with x, r2=1.0000005960464478, c=1
# fixing (0,17,0) with 0
# fixing (0,17,1) with 0
# fixing (0,17,2) with x^2, r2=0.9943322539329529, c=2
# fixing (0,17,3) with 0
# fixing (0,17,4) with 0
# fixing (0,17,5) with x^2, r2=0.9868436455726624, c=2
# fixing (0,17,6) with x^2, r2=0.9970659017562866, c=2
# fixing (0,17,7) with sin, r2=0.994304358959198, c=2
# fixing (0,17,8) with x, r2=0.9017801880836487, c=1
# fixing (0,17,9) with x, r2=0.5183218717575073, c=1
# fixing (0,17,10) with x, r2=0.7110558748245239, c=1
# fixing (0,17,11) with sin, r2=0.9971808195114136, c=2
# fixing (0,17,12) with sin, r2=0.9942517280578613, c=2
# fixing (0,17,13) with x^2, r2=0.9863276481628418, c=2
# fixing (0,17,14) with x^2, r2=0.9875406622886658, c=2
# fixing (0,18,0) with 0
# fixing (0,18,1) with 0
# fixing (0,18,2) with 0
# fixing (0,18,3) with 0
# fixing (0,18,4) with 0
# fixing (0,18,5) with sin, r2=0.9993672370910645, c=2
# fixing (0,18,6) with 0
# fixing (0,18,7) with 0
# fixing (0,18,8) with x, r2=0.3642237186431885, c=1
# fixing (0,18,9) with x, r2=0.9750580787658691, c=1
# fixing (0,18,10) with x, r2=0.9538486003875732, c=1
# fixing (0,18,11) with x, r2=0.279860258102417, c=1
# fixing (0,18,12) with sin, r2=0.9632023572921753, c=2
# fixing (0,18,13) with 0
# fixing (0,18,14) with 0
# fixing (0,19,0) with sin, r2=0.9974149465560913, c=2
# fixing (0,19,1) with 0
# fixing (0,19,2) with 0
# fixing (0,19,3) with 0
# fixing (0,19,4) with 0
# fixing (0,19,5) with sin, r2=0.9948030114173889, c=2
# fixing (0,19,6) with sin, r2=0.9986315369606018, c=2
# fixing (0,19,7) with sin, r2=0.9875215888023376, c=2
# fixing (0,19,8) with x, r2=0.7410814166069031, c=1
# fixing (0,19,9) with x, r2=0.9927432537078857, c=1
# fixing (0,19,10) with x, r2=0.9871596693992615, c=1
# fixing (0,19,11) with sin, r2=0.99953693151474, c=2
# fixing (0,19,12) with sin, r2=0.9988308548927307, c=2
# fixing (0,19,13) with 0
# fixing (0,19,14) with 0
# fixing (0,20,0) with 0
# fixing (0,20,1) with 0
# fixing (0,20,2) with 0
# fixing (0,20,3) with 0
# fixing (0,20,4) with 0
# fixing (0,20,5) with x, r2=0.36667004227638245, c=1
# fixing (0,20,6) with 0
# fixing (0,20,7) with x, r2=0.47960519790649414, c=1
# fixing (0,20,8) with x^2, r2=0.9880971908569336, c=2
# fixing (0,20,9) with sin, r2=0.9746429324150085, c=2
# fixing (0,20,10) with x, r2=0.9818681478500366, c=1
# fixing (0,20,11) with exp, r2=0.9990343451499939, c=2
# fixing (0,20,12) with x, r2=0.889903724193573, c=1
# fixing (0,20,13) with 0
# fixing (0,20,14) with 0
# fixing (0,21,0) with 0
# fixing (0,21,1) with 0
# fixing (0,21,2) with 0
# fixing (0,21,3) with 0
# fixing (0,21,4) with 0
# fixing (0,21,5) with 0
# fixing (0,21,6) with 0
# fixing (0,21,7) with 0
# fixing (0,21,8) with 0
# fixing (0,21,9) with 0
# fixing (0,21,10) with 0
# fixing (0,21,11) with 0
# fixing (0,21,12) with 0
# fixing (0,21,13) with 0
# fixing (0,21,14) with 0
# fixing (0,22,0) with 0
# fixing (0,22,1) with 0
# fixing (0,22,2) with 0
# fixing (0,22,3) with 0
# fixing (0,22,4) with 0
# fixing (0,22,5) with 0
# fixing (0,22,6) with 0
# fixing (0,22,7) with x, r2=0.5890853404998779, c=1
# fixing (0,22,8) with x, r2=0.819977343082428, c=1
# fixing (0,22,9) with sin, r2=0.9984553456306458, c=2
# fixing (0,22,10) with sin, r2=0.999805212020874, c=2
# fixing (0,22,11) with 0
# fixing (0,22,12) with exp, r2=0.9863569140434265, c=2
# fixing (0,22,13) with sin, r2=0.9979966282844543, c=2
# fixing (0,22,14) with 0
# fixing (0,23,0) with 0
# fixing (0,23,1) with 0
# fixing (0,23,2) with 0
# fixing (0,23,3) with 0
# fixing (0,23,4) with 0
# fixing (0,23,5) with 0
# fixing (0,23,6) with 0
# fixing (0,23,7) with tan, r2=1.0000008344650269, c=3
# fixing (0,23,8) with sin, r2=0.9999969005584717, c=2
# fixing (0,23,9) with tan, r2=0.999996542930603, c=3
# fixing (0,23,10) with 0
# fixing (0,23,11) with x^2, r2=0.9999983906745911, c=2
# fixing (0,23,12) with x^2, r2=0.9999159574508667, c=2
# fixing (0,23,13) with 0
# fixing (0,23,14) with 0
# fixing (0,24,0) with 0
# fixing (0,24,1) with 0
# fixing (0,24,2) with 0
# fixing (0,24,3) with 0
# fixing (0,24,4) with 0
# fixing (0,24,5) with sin, r2=0.9980272054672241, c=2
# fixing (0,24,6) with 0
# fixing (0,24,7) with x, r2=0.9436683058738708, c=1
# fixing (0,24,8) with x, r2=0.8854243159294128, c=1
# fixing (0,24,9) with x, r2=0.19610562920570374, c=1
# fixing (0,24,10) with sin, r2=0.9886099696159363, c=2
# fixing (0,24,11) with x, r2=0.9644221067428589, c=1
# fixing (0,24,12) with x, r2=0.9944419860839844, c=1
# fixing (0,24,13) with x, r2=0.9013310670852661, c=1
# fixing (0,24,14) with sin, r2=0.9962761402130127, c=2
# fixing (0,25,0) with 0
# fixing (0,25,1) with 0
# fixing (0,25,2) with 0
# fixing (0,25,3) with 0
# fixing (0,25,4) with 0
# fixing (0,25,5) with 0
# fixing (0,25,6) with x, r2=0.778914749622345, c=1
# fixing (0,25,7) with x, r2=0.8008273243904114, c=1
# fixing (0,25,8) with x, r2=0.8331272602081299, c=1
# fixing (0,25,9) with x, r2=0.8277676105499268, c=1
# fixing (0,25,10) with x, r2=0.8422064781188965, c=1
# fixing (0,25,11) with 0
# fixing (0,25,12) with sin, r2=0.9866823554039001, c=2
# fixing (0,25,13) with x, r2=0.7482011914253235, c=1
# fixing (0,25,14) with 0
# fixing (0,26,0) with 0
# fixing (0,26,1) with 0
# fixing (0,26,2) with 0
# fixing (0,26,3) with 0
# fixing (0,26,4) with 0
# fixing (0,26,5) with 0
# fixing (0,26,6) with sin, r2=0.9983783960342407, c=2
# fixing (0,26,7) with x, r2=0.9160592555999756, c=1
# fixing (0,26,8) with sin, r2=0.9845901727676392, c=2
# fixing (0,26,9) with x, r2=0.21049411594867706, c=1
# fixing (0,26,10) with sin, r2=0.9992673397064209, c=2
# fixing (0,26,11) with 0
# fixing (0,26,12) with sin, r2=0.9745464324951172, c=2
# fixing (0,26,13) with 0
# fixing (0,26,14) with 0
# fixing (0,27,0) with 0
# fixing (0,27,1) with 0
# fixing (0,27,2) with 0
# fixing (0,27,3) with 0
# fixing (0,27,4) with sin, r2=0.9980748295783997, c=2
# fixing (0,27,5) with 0
# fixing (0,27,6) with 0
# fixing (0,27,7) with x, r2=0.009151364676654339, c=1
# fixing (0,27,8) with x, r2=0.5775656700134277, c=1
# fixing (0,27,9) with sin, r2=0.9987267851829529, c=2
# fixing (0,27,10) with sin, r2=0.9996711015701294, c=2
# fixing (0,27,11) with x, r2=0.166619673371315, c=1
# fixing (0,27,12) with x, r2=0.17778655886650085, c=1
# fixing (0,27,13) with x, r2=0.9783759117126465, c=1
# fixing (0,27,14) with x, r2=0.39847442507743835, c=1
# fixing (0,28,0) with x, r2=0.8233304023742676, c=1
# fixing (0,28,1) with x^2, r2=0.9970255494117737, c=2
# fixing (0,28,2) with 0
# fixing (0,28,3) with 0
# fixing (0,28,4) with 0
# fixing (0,28,5) with 0
# fixing (0,28,6) with 0
# fixing (0,28,7) with x, r2=0.07111987471580505, c=1
# fixing (0,28,8) with x, r2=0.28171372413635254, c=1
# fixing (0,28,9) with sin, r2=0.9871587753295898, c=2
# fixing (0,28,10) with sin, r2=0.9590252637863159, c=2
# fixing (0,28,11) with sin, r2=0.9738109111785889, c=2
# fixing (0,28,12) with x, r2=0.11409907042980194, c=1
# fixing (0,28,13) with sin, r2=0.994579017162323, c=2
# fixing (0,28,14) with x, r2=0.9740981459617615, c=1
# fixing (0,29,0) with 0
# fixing (0,29,1) with 0
# fixing (0,29,2) with 0
# fixing (0,29,3) with 0
# fixing (0,29,4) with sin, r2=0.9998976588249207, c=2
# fixing (0,29,5) with sin, r2=0.9998317956924438, c=2
# fixing (0,29,6) with 0
# fixing (0,29,7) with sin, r2=0.9998288154602051, c=2
# fixing (0,29,8) with sin, r2=0.9999215602874756, c=2
# fixing (0,29,9) with 0
# fixing (0,29,10) with 0
# fixing (0,29,11) with 0
# fixing (0,29,12) with sin, r2=0.9998724460601807, c=2
# fixing (0,29,13) with sin, r2=0.9998679161071777, c=2
# fixing (0,29,14) with 0
# fixing (0,30,0) with 0
# fixing (0,30,1) with 0
# fixing (0,30,2) with 0
# fixing (0,30,3) with 0
# fixing (0,30,4) with 0
# fixing (0,30,5) with 0
# fixing (0,30,6) with 0
# fixing (0,30,7) with x, r2=0.9935870170593262, c=1
# fixing (0,30,8) with x, r2=0.9924551248550415, c=1
# fixing (0,30,9) with 0
# fixing (0,30,10) with 0
# fixing (0,30,11) with abs, r2=0.9999557733535767, c=3
# fixing (0,30,12) with sin, r2=0.995480477809906, c=2
# fixing (0,30,13) with sin, r2=0.9983025789260864, c=2
# fixing (0,30,14) with 0
# fixing (0,31,0) with 0
# fixing (0,31,1) with 0
# fixing (0,31,2) with 0
# fixing (0,31,3) with 0
# fixing (0,31,4) with 0
# fixing (0,31,5) with 0
# fixing (0,31,6) with x, r2=0.9999677538871765, c=1
# fixing (0,31,7) with x, r2=0.9997715950012207, c=1
# fixing (0,31,8) with x, r2=0.9999364614486694, c=1
# fixing (0,31,9) with sin, r2=0.9999606609344482, c=2
# fixing (0,31,10) with x, r2=0.9997197389602661, c=1
# fixing (0,31,11) with x, r2=0.9999224543571472, c=1
# fixing (0,31,12) with x, r2=0.9999483823776245, c=1
# fixing (0,31,13) with 0
# fixing (0,31,14) with 0
# fixing (0,32,0) with 0
# fixing (0,32,1) with 0
# fixing (0,32,2) with 0
# fixing (0,32,3) with 0
# fixing (0,32,4) with 0
# fixing (0,32,5) with 0
# fixing (0,32,6) with 0
# fixing (0,32,7) with x^2, r2=1.0000008344650269, c=2
# fixing (0,32,8) with x^2, r2=1.000001072883606, c=2
# fixing (0,32,9) with x^2, r2=1.0000009536743164, c=2
# fixing (0,32,10) with 0
# fixing (0,32,11) with x^2, r2=1.0000008344650269, c=2
# fixing (0,32,12) with x, r2=1.0000007152557373, c=1
# fixing (0,32,13) with 0
# fixing (0,32,14) with x, r2=0.9999921321868896, c=1
# fixing (0,33,0) with 0
# fixing (0,33,1) with 0
# fixing (0,33,2) with 0
# fixing (0,33,3) with 0
# fixing (0,33,4) with 0
# fixing (0,33,5) with 0
# fixing (0,33,6) with 0
# fixing (0,33,7) with x, r2=0.010469119995832443, c=1
# fixing (0,33,8) with sin, r2=0.9472695589065552, c=2
# fixing (0,33,9) with exp, r2=0.9685205817222595, c=2
# fixing (0,33,10) with x, r2=0.43875738978385925, c=1
# fixing (0,33,11) with 0
# fixing (0,33,12) with exp, r2=0.9833164215087891, c=2
# fixing (0,33,13) with exp, r2=0.9785301089286804, c=2
# fixing (0,33,14) with exp, r2=0.9790306687355042, c=2
# fixing (0,34,0) with 0
# fixing (0,34,1) with 0
# fixing (0,34,2) with 0
# fixing (0,34,3) with 0
# fixing (0,34,4) with 0
# fixing (0,34,5) with x, r2=0.7068240642547607, c=1
# fixing (0,34,6) with 0
# fixing (0,34,7) with exp, r2=0.9975192546844482, c=2
# fixing (0,34,8) with x, r2=0.6156548261642456, c=1
# fixing (0,34,9) with x, r2=0.7104799747467041, c=1
# fixing (0,34,10) with sin, r2=0.9760788083076477, c=2
# fixing (0,34,11) with 0
# fixing (0,34,12) with 0
# fixing (0,34,13) with 0
# fixing (0,34,14) with 0
# fixing (0,35,0) with 0
# fixing (0,35,1) with 0
# fixing (0,35,2) with 0
# fixing (0,35,3) with 0
# fixing (0,35,4) with 0
# fixing (0,35,5) with sin, r2=0.9976962208747864, c=2
# fixing (0,35,6) with sin, r2=0.9984679818153381, c=2
# fixing (0,35,7) with x, r2=0.6233492493629456, c=1
# fixing (0,35,8) with 0
# fixing (0,35,9) with sin, r2=0.9999485015869141, c=2
# fixing (0,35,10) with sin, r2=0.9968670010566711, c=2
# fixing (0,35,11) with sin, r2=0.9892077445983887, c=2
# fixing (0,35,12) with x, r2=0.9277045726776123, c=1
# fixing (0,35,13) with x, r2=0.7825176119804382, c=1
# fixing (0,35,14) with sin, r2=0.9980435967445374, c=2
# fixing (0,36,0) with 0
# fixing (0,36,1) with 0
# fixing (0,36,2) with 0
# fixing (0,36,3) with 0
# fixing (0,36,4) with 0
# fixing (0,36,5) with 0
# fixing (0,36,6) with 0
# fixing (0,36,7) with x, r2=0.22564291954040527, c=1
# fixing (0,36,8) with sin, r2=0.981438398361206, c=2
# fixing (0,36,9) with x, r2=0.9295676350593567, c=1
# fixing (0,36,10) with x, r2=0.9506085515022278, c=1
# fixing (0,36,11) with sin, r2=0.99159836769104, c=2
# fixing (0,36,12) with sin, r2=0.9962422847747803, c=2
# fixing (0,36,13) with x^2, r2=0.9991777539253235, c=2
# fixing (0,36,14) with x^2, r2=0.9893096685409546, c=2
# fixing (0,37,0) with 0
# fixing (0,37,1) with 0
# fixing (0,37,2) with 0
# fixing (0,37,3) with 0
# fixing (0,37,4) with 0
# fixing (0,37,5) with 0
# fixing (0,37,6) with x, r2=1.0000004768371582, c=1
# fixing (0,37,7) with x, r2=1.0000008344650269, c=1
# fixing (0,37,8) with x, r2=1.0000008344650269, c=1
# fixing (0,37,9) with x, r2=1.0000007152557373, c=1
# fixing (0,37,10) with x, r2=1.0000007152557373, c=1
# fixing (0,37,11) with 0
# fixing (0,37,12) with x, r2=1.0000008344650269, c=1
# fixing (0,37,13) with 0
# fixing (0,37,14) with x, r2=1.0000007152557373, c=1
# fixing (0,38,0) with 0
# fixing (0,38,1) with 0
# fixing (0,38,2) with 0
# fixing (0,38,3) with 0
# fixing (0,38,4) with 0
# fixing (0,38,5) with 0
# fixing (0,38,6) with x^2, r2=0.9807520508766174, c=2
# fixing (0,38,7) with exp, r2=0.9695819616317749, c=2
# fixing (0,38,8) with 0
# fixing (0,38,9) with x, r2=0.792335033416748, c=1
# fixing (0,38,10) with x, r2=0.8688810467720032, c=1
# fixing (0,38,11) with x, r2=0.962657630443573, c=1
# fixing (0,38,12) with x^2, r2=0.9954452514648438, c=2
# fixing (0,38,13) with 0
# fixing (0,38,14) with 0
# fixing (0,39,0) with 0
# fixing (0,39,1) with 0
# fixing (0,39,2) with 0
# fixing (0,39,3) with 0
# fixing (0,39,4) with 0
# fixing (0,39,5) with exp, r2=0.984856903553009, c=2
# fixing (0,39,6) with 0
# fixing (0,39,7) with exp, r2=0.9907160997390747, c=2
# fixing (0,39,8) with x, r2=0.4367864727973938, c=1
# fixing (0,39,9) with exp, r2=0.9835863709449768, c=2
# fixing (0,39,10) with x, r2=0.44044631719589233, c=1
# fixing (0,39,11) with 0
# fixing (0,39,12) with 0
# fixing (0,39,13) with sqrt, r2=0.9940804839134216, c=2
# fixing (0,39,14) with 0
# fixing (0,40,0) with 0
# fixing (0,40,1) with 0
# fixing (0,40,2) with 0
# fixing (0,40,3) with 0
# fixing (0,40,4) with 0
# fixing (0,40,5) with 0
# fixing (0,40,6) with 0
# fixing (0,40,7) with x, r2=0.1836431920528412, c=1
# fixing (0,40,8) with sin, r2=0.9996401071548462, c=2
# fixing (0,40,9) with 0
# fixing (0,40,10) with 0
# fixing (0,40,11) with sin, r2=0.9934548139572144, c=2
# fixing (0,40,12) with sin, r2=0.9953186511993408, c=2
# fixing (0,40,13) with 0
# fixing (0,40,14) with x^2, r2=0.9992225170135498, c=2
# fixing (0,41,0) with 0
# fixing (0,41,1) with 0
# fixing (0,41,2) with 0
# fixing (0,41,3) with 0
# fixing (0,41,4) with 0
# fixing (0,41,5) with sin, r2=1.0000004768371582, c=2
# fixing (0,41,6) with 0
# fixing (0,41,7) with sin, r2=1.0000003576278687, c=2
# fixing (0,41,8) with x^2, r2=0.9999968409538269, c=2
# fixing (0,41,9) with 0
# fixing (0,41,10) with sin, r2=1.000000238418579, c=2
# fixing (0,41,11) with sin, r2=1.0000005960464478, c=2
# fixing (0,41,12) with 0
# fixing (0,41,13) with 0
# fixing (0,41,14) with sin, r2=1.0000008344650269, c=2
# fixing (0,42,0) with x, r2=0.9722248911857605, c=1
# fixing (0,42,1) with sin, r2=0.9997175931930542, c=2
# fixing (0,42,2) with 0
# fixing (0,42,3) with 0
# fixing (0,42,4) with sin, r2=0.9983704686164856, c=2
# fixing (0,42,5) with sin, r2=0.9989018440246582, c=2
# fixing (0,42,6) with 0
# fixing (0,42,7) with x, r2=0.6727508902549744, c=1
# fixing (0,42,8) with x, r2=0.9165868163108826, c=1
# fixing (0,42,9) with x, r2=0.9893513321876526, c=1
# fixing (0,42,10) with x, r2=0.8458095192909241, c=1
# fixing (0,42,11) with x^2, r2=0.999647319316864, c=2
# fixing (0,42,12) with x, r2=0.2736053466796875, c=1
# fixing (0,42,13) with x, r2=0.8695484399795532, c=1
# fixing (0,42,14) with x^2, r2=0.999907910823822, c=2
# fixing (0,43,0) with 0
# fixing (0,43,1) with 0
# fixing (0,43,2) with 0
# fixing (0,43,3) with 0
# fixing (0,43,4) with 0
# fixing (0,43,5) with 0
# fixing (0,43,6) with 0
# fixing (0,43,7) with x, r2=0.08456998318433762, c=1
# fixing (0,43,8) with x, r2=0.7740435600280762, c=1
# fixing (0,43,9) with x, r2=0.1938713639974594, c=1
# fixing (0,43,10) with sin, r2=0.9997918009757996, c=2
# fixing (0,43,11) with x, r2=0.5345884561538696, c=1
# fixing (0,43,12) with sin, r2=0.941554605960846, c=2
# fixing (0,43,13) with x, r2=0.8556694388389587, c=1
# fixing (0,43,14) with tanh, r2=0.9998734593391418, c=3
# fixing (0,44,0) with 0
# fixing (0,44,1) with 0
# fixing (0,44,2) with 0
# fixing (0,44,3) with 0
# fixing (0,44,4) with 0
# fixing (0,44,5) with sin, r2=0.9835517406463623, c=2
# fixing (0,44,6) with sin, r2=0.9858946800231934, c=2
# fixing (0,44,7) with sin, r2=0.9981496334075928, c=2
# fixing (0,44,8) with x^2, r2=0.9939472675323486, c=2
# fixing (0,44,9) with sin, r2=0.9665764570236206, c=2
# fixing (0,44,10) with sin, r2=0.98035728931427, c=2
# fixing (0,44,11) with x^2, r2=0.9874852895736694, c=2
# fixing (0,44,12) with x, r2=0.10293775796890259, c=1
# fixing (0,44,13) with 0
# fixing (0,44,14) with 0
# fixing (0,45,0) with sin, r2=0.9999627470970154, c=2
# fixing (0,45,1) with sin, r2=0.9999624490737915, c=2
# fixing (0,45,2) with 0
# fixing (0,45,3) with 0
# fixing (0,45,4) with sin, r2=0.9999589920043945, c=2
# fixing (0,45,5) with sin, r2=0.9999600052833557, c=2
# fixing (0,45,6) with sin, r2=0.999957799911499, c=2
# fixing (0,45,7) with sin, r2=0.9908730983734131, c=2
# fixing (0,45,8) with sin, r2=0.9999220371246338, c=2
# fixing (0,45,9) with sin, r2=0.9999761581420898, c=2
# fixing (0,45,10) with sin, r2=0.9999650120735168, c=2
# fixing (0,45,11) with x, r2=0.999369204044342, c=1
# fixing (0,45,12) with x, r2=0.9995149374008179, c=1
# fixing (0,45,13) with 0
# fixing (0,45,14) with 0
# fixing (0,46,0) with 0
# fixing (0,46,1) with 0
# fixing (0,46,2) with 0
# fixing (0,46,3) with 0
# fixing (0,46,4) with 0
# fixing (0,46,5) with 0
# fixing (0,46,6) with 0
# fixing (0,46,7) with x, r2=0.9999276995658875, c=1
# fixing (0,46,8) with x, r2=0.9999234080314636, c=1
# fixing (0,46,9) with exp, r2=1.000001311302185, c=2
# fixing (0,46,10) with 0
# fixing (0,46,11) with x^2, r2=1.000001311302185, c=2
# fixing (0,46,12) with x^2, r2=1.000001311302185, c=2
# fixing (0,46,13) with x^2, r2=1.0000008344650269, c=2
# fixing (0,46,14) with exp, r2=1.0000011920928955, c=2
# fixing (0,47,0) with 0
# fixing (0,47,1) with 0
# fixing (0,47,2) with 0
# fixing (0,47,3) with 0
# fixing (0,47,4) with 0
# fixing (0,47,5) with x^2, r2=1.0000007152557373, c=2
# fixing (0,47,6) with x^2, r2=1.000001311302185, c=2
# fixing (0,47,7) with x^2, r2=1.000001072883606, c=2
# fixing (0,47,8) with 0
# fixing (0,47,9) with x^2, r2=1.0000009536743164, c=2
# fixing (0,47,10) with x^2, r2=1.0000014305114746, c=2
# fixing (0,47,11) with exp, r2=1.0000009536743164, c=2
# fixing (0,47,12) with 0
# fixing (0,47,13) with 0
# fixing (0,47,14) with x^2, r2=1.000001311302185, c=2
# fixing (0,48,0) with 0
# fixing (0,48,1) with 0
# fixing (0,48,2) with 0
# fixing (0,48,3) with 0
# fixing (0,48,4) with 0
# fixing (0,48,5) with x, r2=0.9926598072052002, c=1
# fixing (0,48,6) with sin, r2=0.9994713068008423, c=2
# fixing (0,48,7) with sin, r2=0.9984306693077087, c=2
# fixing (0,48,8) with sin, r2=0.9968467354774475, c=2
# fixing (0,48,9) with 0
# fixing (0,48,10) with 0
# fixing (0,48,11) with sin, r2=0.9992281794548035, c=2
# fixing (0,48,12) with 0
# fixing (0,48,13) with 0
# fixing (0,48,14) with x, r2=0.9963129162788391, c=1
# fixing (0,49,0) with 0
# fixing (0,49,1) with 0
# fixing (0,49,2) with 0
# fixing (0,49,3) with 0
# fixing (0,49,4) with 0
# fixing (0,49,5) with 0
# fixing (0,49,6) with 0
# fixing (0,49,7) with exp, r2=1.0000008344650269, c=2
# fixing (0,49,8) with 0
# fixing (0,49,9) with 0
# fixing (0,49,10) with x^2, r2=1.0000007152557373, c=2
# fixing (0,49,11) with sin, r2=1.0000004768371582, c=2
# fixing (0,49,12) with x^2, r2=1.0000007152557373, c=2
# fixing (0,49,13) with 0
# fixing (0,49,14) with 0
# fixing (0,50,0) with 0
# fixing (0,50,1) with 0
# fixing (0,50,2) with 0
# fixing (0,50,3) with 0
# fixing (0,50,4) with 0
# fixing (0,50,5) with 0
# fixing (0,50,6) with 0
# fixing (0,50,7) with x, r2=1.0000015497207642, c=1
# fixing (0,50,8) with 0
# fixing (0,50,9) with 0
# fixing (0,50,10) with 0
# fixing (0,50,11) with 0
# fixing (0,50,12) with 0
# fixing (0,50,13) with 0
# fixing (0,50,14) with 0
# fixing (0,51,0) with 0
# fixing (0,51,1) with 0
# fixing (0,51,2) with 0
# fixing (0,51,3) with 0
# fixing (0,51,4) with 0
# fixing (0,51,5) with 0
# fixing (0,51,6) with exp, r2=1.000001311302185, c=2
# fixing (0,51,7) with x^2, r2=1.000001311302185, c=2
# fixing (0,51,8) with exp, r2=1.0000011920928955, c=2
# fixing (0,51,9) with exp, r2=1.000001072883606, c=2
# fixing (0,51,10) with 0
# fixing (0,51,11) with exp, r2=1.0000009536743164, c=2
# fixing (0,51,12) with 0
# fixing (0,51,13) with x^2, r2=1.0000008344650269, c=2
# fixing (0,51,14) with 0
# fixing (0,52,0) with 0
# fixing (0,52,1) with 0
# fixing (0,52,2) with 0
# fixing (0,52,3) with 0
# fixing (0,52,4) with x, r2=1.0000017881393433, c=1
# fixing (0,52,5) with 0
# fixing (0,52,6) with x, r2=1.0000020265579224, c=1
# fixing (0,52,7) with x, r2=0.9999979734420776, c=1
# fixing (0,52,8) with 0
# fixing (0,52,9) with x, r2=1.0000015497207642, c=1
# fixing (0,52,10) with 0
# fixing (0,52,11) with 0
# fixing (0,52,12) with 0
# fixing (0,52,13) with 0
# fixing (0,52,14) with x, r2=1.0000014305114746, c=1
# fixing (0,53,0) with 0
# fixing (0,53,1) with 0
# fixing (0,53,2) with 0
# fixing (0,53,3) with 0
# fixing (0,53,4) with 0
# fixing (0,53,5) with 0
# fixing (0,53,6) with 0
# fixing (0,53,7) with x, r2=1.0000009536743164, c=1
# fixing (0,53,8) with x, r2=1.0000005960464478, c=1
# fixing (0,53,9) with 0
# fixing (0,53,10) with 0
# fixing (0,53,11) with 0
# fixing (0,53,12) with 0
# fixing (0,53,13) with 0
# fixing (0,53,14) with x, r2=1.0000007152557373, c=1
# fixing (0,54,0) with 0
# fixing (0,54,1) with 0
# fixing (0,54,2) with x, r2=6.184669820050159e-20, c=1
# fixing (0,54,3) with 0
# fixing (0,54,4) with 0
# fixing (0,54,5) with x, r2=0.0, c=1
# fixing (0,54,6) with 0
# fixing (0,54,7) with x, r2=0.0, c=1
# fixing (0,54,8) with x, r2=1.5461674550125398e-20, c=1
# fixing (0,54,9) with x, r2=1.5461674550125398e-20, c=1
# fixing (0,54,10) with x, r2=1.5099291489747962e-21, c=1
# fixing (0,54,11) with x, r2=1.5461674550125398e-20, c=1
# fixing (0,54,12) with x, r2=3.478876733388536e-20, c=1
# fixing (0,54,13) with x, r2=0.0, c=1
# fixing (0,54,14) with x, r2=0.0, c=1
# fixing (0,55,0) with 0
# fixing (0,55,1) with 0
# fixing (0,55,2) with 0
# fixing (0,55,3) with 0
# fixing (0,55,4) with sin, r2=0.999739408493042, c=2
# fixing (0,55,5) with 0
# fixing (0,55,6) with 0
# fixing (0,55,7) with sin, r2=0.9997794032096863, c=2
# fixing (0,55,8) with sin, r2=0.9997283220291138, c=2
# fixing (0,55,9) with 0
# fixing (0,55,10) with sin, r2=0.9997153282165527, c=2
# fixing (0,55,11) with 0
# fixing (0,55,12) with 0
# fixing (0,55,13) with sin, r2=0.9994509220123291, c=2
# fixing (0,55,14) with sin, r2=0.9998056292533875, c=2
# fixing (0,56,0) with 0
# fixing (0,56,1) with 0
# fixing (0,56,2) with 0
# fixing (0,56,3) with 0
# fixing (0,56,4) with 0
# fixing (0,56,5) with sin, r2=0.9996041059494019, c=2
# fixing (0,56,6) with 0
# fixing (0,56,7) with sin, r2=0.9951122999191284, c=2
# fixing (0,56,8) with sin, r2=0.9933971762657166, c=2
# fixing (0,56,9) with x, r2=0.46056225895881653, c=1
# fixing (0,56,10) with sin, r2=0.9975472092628479, c=2
# fixing (0,56,11) with x, r2=0.8350142240524292, c=1
# fixing (0,56,12) with sin, r2=0.997381329536438, c=2
# fixing (0,56,13) with 0
# fixing (0,56,14) with 0
# fixing (0,57,0) with 0
# fixing (0,57,1) with 0
# fixing (0,57,2) with 0
# fixing (0,57,3) with 0
# fixing (0,57,4) with 0
# fixing (0,57,5) with 0
# fixing (0,57,6) with 0
# fixing (0,57,7) with x, r2=0.31803685426712036, c=1
# fixing (0,57,8) with x, r2=0.8891966938972473, c=1
# fixing (0,57,9) with x^2, r2=0.9879892468452454, c=2
# fixing (0,57,10) with 0
# fixing (0,57,11) with x, r2=0.6210808753967285, c=1
# fixing (0,57,12) with x, r2=0.47005322575569153, c=1
# fixing (0,57,13) with x^2, r2=0.9848895072937012, c=2
# fixing (0,57,14) with x^2, r2=0.9841260313987732, c=2
# fixing (1,0,0) with sin, r2=0.9999872446060181, c=2
# fixing (1,0,1) with 0
# fixing (1,0,2) with sin, r2=0.9996752142906189, c=2
# fixing (1,1,0) with 0
# fixing (1,1,1) with sin, r2=0.9999540448188782, c=2
# fixing (1,1,2) with x^2, r2=0.9989258646965027, c=2
# fixing (1,2,0) with 0
# fixing (1,2,1) with 0
# fixing (1,2,2) with x^2, r2=1.0000001192092896, c=2
# fixing (1,3,0) with 0
# fixing (1,3,1) with 0
# fixing (1,3,2) with 0
# fixing (1,4,0) with x, r2=0.4227191209793091, c=1
# fixing (1,4,1) with 0
# fixing (1,4,2) with sin, r2=0.9898363351821899, c=2
# fixing (1,5,0) with x, r2=0.8943199515342712, c=1
# fixing (1,5,1) with sin, r2=0.9994732737541199, c=2
# fixing (1,5,2) with x, r2=0.44420161843299866, c=1
# fixing (1,6,0) with tanh, r2=0.9998472929000854, c=3
# fixing (1,6,1) with exp, r2=0.9801317453384399, c=2
# fixing (1,6,2) with tanh, r2=0.9997715950012207, c=3
# fixing (1,7,0) with exp, r2=0.999887228012085, c=2
# fixing (1,7,1) with exp, r2=0.9999009370803833, c=2
# fixing (1,7,2) with sin, r2=0.9997513294219971, c=2
# fixing (1,8,0) with exp, r2=0.9955897331237793, c=2
# fixing (1,8,1) with sin, r2=0.9974725246429443, c=2
# fixing (1,8,2) with x, r2=0.28619518876075745, c=1
# fixing (1,9,0) with x, r2=0.9246439337730408, c=1
# fixing (1,9,1) with x, r2=0.9760510921478271, c=1
# fixing (1,9,2) with x, r2=0.957782506942749, c=1
# saving model version 0.3

# %%
y_pred = dragon_kaam.predict(x_test, t_test)
y_pred_0 = y_pred['y_pred_0']
y_pred_1 = y_pred['y_pred_1']
y_pred_f = y_pred['y_pred_f']
ite_pred = y_pred_1 - y_pred_0
mse_kaam_formula = np.mean((y_test - y_pred_f) ** 2)
pehe_kaam_formula = np.sqrt(np.mean((real_ite_test - y_pred_f) ** 2))
print(f'MSE KAN formula: {mse_kaam_formula}, PEHE KAN formula: {pehe_kaam_formula}')
print(f'Predicted ATE formula: {ite_pred.mean()}, Real ATE: {real_ite_test.mean()}')
# evaluate formula performance

# y_pred = symb_s_kaam.predict(x_test)
# y_pred_0 = y_pred[:, 0]
# y_pred_1 = y_pred[:, 1]
# y_pred_f = t_test * y_pred_1 + (1 - t_test) * y_pred_0
# ite_pred = y_pred_1 - y_pred_0
# mse_formula = np.mean((y_test - y_pred_f)**2)
# pehe_formula = np.sqrt(np.mean((real_ite_test - ite_pred)**2))
# print(f'MSE formula: {mse_formula}, PEHE formula: {pehe_formula}')

print(formulas)
# extract the CATE
# in this case the CATE is the term that corresponds to the treatment 't'
# Break into additive terms

# Rebuild the expression
cate_formula = formulas[1] - formulas[0]

x_cols_ = ['x_' + col[1:] for col in x_cols]
test_df = pd.DataFrame(data_test.loc[:, x_cols].to_numpy(), columns=x_cols_)

# ite_pred_formula = eval_expr_on_df(cate_formula, data_test)
# pehe_formula_cate = np.sqrt(np.mean((real_ite_test - ite_pred_formula)**2))
# print(f'PEHE formula cate: {pehe_formula_cate}')
ite_pred_formula = get_formula_values(cate_formula,  test_df.copy())
pehe_formula_cate = np.sqrt(np.mean((real_ite_test - ite_pred_formula) ** 2))
print(f'PEHE formula cate: {pehe_formula_cate}')
print(f'ATE formula cate: {ite_pred_formula.mean()}, Real ATE: {real_ite_test.mean()}')
# formula_0_rounded = sp.sympify(sp.nsimplify(formulas[0], tolerance=1e-2))
# y_pred_0_trunc = eval_expr_on_df(formula_0_rounded, data_test)
# formula_1_rounded = sp.sympify(sp.nsimplify(formulas[0], tolerance=1e-2))
# y_pred_1_trunc = eval_expr_on_df(formula_1_rounded, data_test)
# y_pred_f_trunc = y_pred_0_trunc * (1 - t_test[:,0]) + y_pred_1_trunc * t_test[:,0]
# ite_pred_trunc = y_pred_1_trunc - y_pred_0_trunc
# mse_formula_trunc = np.mean((y_test[:,0] - y_pred_f_trunc)**2)
# pehe_formula_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_trunc)**2))
# print(f'MSE formula truncated: {mse_formula_trunc}, PEHE formula truncated: {pehe_formula_trunc}')


# truncate
formulas_trun = [ex_round(f, 2) for f in formulas]
y_pred_0_trunc = get_formula_values(formulas_trun[0],  test_df.copy())
y_pred_1_trunc = get_formula_values(formulas_trun[1],  test_df.copy())
y_pred_f_trunc = y_pred_0_trunc * (1 - t_test[:, 0]) + y_pred_1_trunc * t_test[:, 0]
ite_pred_trunc = y_pred_1_trunc - y_pred_0_trunc
mse_formula_trunc = np.mean((y_test[:, 0] - y_pred_f_trunc) ** 2)
pehe_formula_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_trunc) ** 2))
print(f'MSE formula truncated: {mse_formula_trunc}, PEHE formula truncated: {pehe_formula_trunc}')
print(f'Predicted ATE formula truncated: {ite_pred_trunc.mean()}, Real ATE: {real_ite_test.mean()}')

# #print pehe with cate formula truncated
# cate_formula_trunc = formulas_1_rounded - formulas_0_rounded
# ite_pred_formula_trunc = eval_expr_on_df(cate_formula_trunc, data_test)
# pehe_formula_cate_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_formula_trunc)**2))
# print(f'PEHE formula cate truncated: {pehe_formula_cate_trunc}')

#print pehe with cate formula truncated
cate_formula_trunc = formulas_trun[1] - formulas_trun[0]
ite_pred_formula_trunc = get_formula_values(cate_formula_trunc, test_df.copy())
pehe_formula_cate_trunc = np.sqrt(np.mean((real_ite_test - ite_pred_formula_trunc) ** 2))
print(f'PEHE formula cate truncated: {pehe_formula_cate_trunc}')
print(f'ATE formula cate truncated: {ite_pred_formula_trunc.mean()}, Real ATE: {real_ite_test.mean()}')
present = {s.name for s in formulas[0].free_symbols}
print(present)
ausent = set(x_cols) - present
print(ausent)
n_feats = len(list(present))
# Out:
# MSE KAN formula: 9.452967830202796, PEHE KAN formula: 5.077772417046369
# Predicted ATE formula: 2.080573558807373, Real ATE: 4.229490757544409
# [-0.0138*x_5 - 0.0161*x_53 - 0.0007*(-1.5942*x_1 - 8.7925)**2 + 0.0041*(-0.409*x_16 - 7.2934)**2 - 0.217*(-0.099*x_2 + 0.0607*x_26 + 0.102*x_32 - 0.0988*x_38 - 0.1456*x_53 + 0.009*(-1.0377*x_16 - 6.5972)**2 + 0.0016*(-4.4941*x_18 - 7.4151)**2 - 0.001*(-4.9898*x_39 - 8.5834)**2 + 0.0776*(-0.12*x_48 - 9.9959)**2 - 2.0393*exp(0.0789*x_52) + 0.4386*sin(5.0066*x_10 - 9.2191) + 0.6519*sin(0.4076*x_12 + 1.9907) + 0.3954*sin(0.3852*x_13 + 2.0046) + 0.135*sin(0.6656*x_20 + 8.4305) + 0.2448*sin(0.4446*x_27 - 7.39) + 0.5021*sin(0.3758*x_36 + 5.1904) + 0.3711*sin(0.5137*x_4 + 5.1971) + 0.522*sin(0.3226*x_45 - 1.2654) - 0.2976*sin(8.6072*x_46 - 9.0207) - 0.9974*sin(9.8146*x_49 - 5.4146) + 0.5101*sin(4.6011*x_9 - 8.5994) - 6.8547)*(-0.0205*x_21 + 0.0496*x_35 - 0.1237*x_49 + 0.0695*x_6 - 0.0754*x_7 + 0.0054*(-1.206*x_16 - 6.367)**2 + 0.0006*(-7.4*x_18 - 9.9998)**2 + 0.0377*(-0.2062*x_48 - 7.1386)**2 - 0.0903*exp(1.1392*x_40) + 0.31*sin(5.205*x_12 - 4.9935) - 0.3617*sin(0.3882*x_13 + 1.991) - 0.2595*sin(5.4114*x_14 - 6.2059) + 0.2668*sin(8.7994*x_15 - 2.1842) - 0.4179*sin(0.3559*x_19 + 1.9584) - 0.3732*sin(0.3658*x_20 - 1.2133) - 0.7698*sin(9.4022*x_25 + 5.3929) - 0.393*sin(8.3852*x_30 - 1.381) - 0.2087*sin(0.4843*x_36 - 4.1256) + 0.2832*sin(6.7423*x_42 + 1.8286) + 0.6526*sin(0.3178*x_43 + 5.127) + 0.4637*sin(0.2966*x_45 - 1.3266) - 0.1406*sin(8.5867*x_46 + 3.6287) + 0.3227*sin(0.2714*x_5 - 1.0918) - 0.3188*sin(8.9952*x_57 + 5.5944) + 0.3326*sin(0.2164*x_8 - 1.0201) - 0.7204*sin(0.3989*x_9 - 1.0036) + 1.9744) + 0.297*(-0.0177*x_1 - 0.0383*x_25 + 0.058*x_26 - 0.0709*x_28 - 0.026*x_36 - 0.0397*x_4 - 0.0342*x_43 + 0.084*x_44 - 0.1491*x_7 + 0.0204*sqrt(9.8894 - 9.8*x_40) - 0.0183*(-0.6134*x_16 - 7.6545)**2 - 0.0005*(-5.5454*x_18 - 6.7813)**2 + 0.0012*(-2.8233*x_37 - 8.261)**2 + 0.005*(-0.4078*x_47 - 7.0066)**2 - 0.0004*(-4.4088*x_52 - 5.2589)**2 + 0.0015*(-3.4039*x_58 - 6.0031)**2 + 0.0863*exp(0.6702*x_34) + 1.0223*sin(4.9931*x_10 + 9.6006) - 0.5253*sin(0.4054*x_12 + 5.1894) + 0.2291*sin(4.5696*x_13 + 1.4113) - 0.365*sin(8.7999*x_14 - 7.2037) - 1.6887*sin(0.2586*x_23 - 1.3459) - 0.3879*sin(0.428*x_29 + 5.0066) - 0.3045*sin(0.4806*x_3 - 7.4234) - 0.6079*sin(8.3822*x_30 - 7.5734) - 0.2533*sin(4.203*x_31 + 3.6036) - 0.1447*sin(9.5922*x_56 - 7.7893) - 0.4351*sin(0.5326*x_6 - 7.4104) + 0.5283*sin(5.0003*x_8 + 7.8034) - 0.4394*sin(0.3946*x_9 - 4.2083) - 0.412)*(-0.0658*x_1 + 0.0847*x_17 - 0.0155*x_28 + 0.0951*x_29 - 0.1768*x_33 + 0.0964*x_38 - 0.0757*x_4 + 0.0978*x_49 - 0.0479*x_5 + 0.034*x_53 - 0.1119*x_54 + 0.0049*x_55 + 0.0068*(-0.6146*x_16 - 5.5194)**2 - 0.0002*(-9.8762*x_18 - 9.929)**2 - 0.0002*(-8.264*x_37 - 4.036)**2 - 0.0017*(-3.3959*x_41 - 9.3962)**2 - 0.0019*(-3.4747*x_43 - 8.185)**2 + 0.0191*(-0.2106*x_48 - 7.5546)**2 + 0.0009*(-4.8771*x_58 - 9.1358)**2 + 0.1066*exp(0.691*x_34) - 0.1426*sin(6.0124*x_12 - 4.0121) + 0.9843*sin(0.3904*x_13 + 1.9728) - 0.3784*sin(2.6006*x_14 + 8.1914) + 0.181*sin(9.7982*x_15 - 8.189) - 0.7774*sin(9.4101*x_25 - 0.792) + 0.6923*sin(0.2642*x_36 - 1.3342) - 0.6141*sin(5.745*x_42 - 8.7866) + 0.2611*sin(5.2275*x_56 - 5.4186) + 0.4719*sin(0.2158*x_8 + 5.3686) + 0.3677*sin(4.5991*x_9 + 0.7994) + 0.2724*tanh(0.5587*x_44 - 1.0115) - 15.4503 + 17.4195*exp(-0.0098*x_47)) + 0.3973*exp(0.253*(-0.0518*x_1 + 0.0907*x_17 + 0.0202*x_21 - 0.018*x_25 + 0.0113*x_28 - 0.0169*x_29 - 0.2366*x_32 - 0.0979*x_33 - 0.0239*x_36 + 0.0991*x_38 + 0.0219*x_4 + 0.0055*x_43 - 0.0069*x_45 - 0.1809*x_46 + 0.0201*x_58 - 0.0173*x_6 + 0.0348*(8.3163 - 0.1945*x_50)**2 - 0.0011*(-4.2577*x_24 - 6.0921)**2 + 0.0012*(-2.8365*x_39 - 7.1266)**2 + 0.002*(-0.6065*x_47 - 7.523)**2 - 0.0054*exp(1.5366*x_23) + 0.1209*exp(0.7058*x_34) + 0.3865*sin(5.0151*x_10 + 0.3844) + 0.9106*sin(0.4121*x_12 + 1.9862) - 0.4984*sin(6.0027*x_14 + 0.8052) + 2.1732*sin(0.2266*x_18 - 4.3445) + 0.0846*sin(1.0008*x_19 + 4.7983) - 1.0875*sin(0.3954*x_20 - 1.1778) + 1.1683*sin(0.2082*x_26 - 1.1953) - 0.0695*sin(0.5464*x_27 - 1.3927) - 0.3908*sin(8.3802*x_30 - 1.1801) + 0.1896*sin(8.2258* ...
# 100%|██████████| 960/960 [44:17<00:00,  2.77s/it]
# PEHE formula cate: 2.739394304776883
# ATE formula cate: 2.0724885129080115, Real ATE: 4.229490757544409
# 100%|██████████| 960/960 [27:12<00:00,  1.70s/it]
# 100%|██████████| 960/960 [28:46<00:00,  1.80s/it]
# MSE formula truncated: 10.527961262884023, PEHE formula truncated: 3.0660576165487687
# Predicted ATE formula truncated: 1.394575236644213, Real ATE: 4.229490757544409
# 100%|██████████| 960/960 [36:44<00:00,  2.30s/it]
# PEHE formula cate truncated: 3.066057616548771
# ATE formula cate truncated: 1.3945752366442112, Real ATE: 4.229490757544409
# {'x_21', 'x_45', 'x_35', 'x_4', 'x_14', 'x_38', 'x_43', 'x_15', 'x_27', 'x_56', 'x_20', 'x_6', 'x_3', 'x_29', 'x_23', 'x_34', 'x_17', 'x_12', 'x_48', 'x_44', 'x_50', 'x_13', 'x_30', 'x_55', 'x_16', 'x_10', 'x_9', 'x_8', 'x_37', 'x_2', 'x_11', 'x_19', 'x_1', 'x_32', 'x_18', 'x_53', 'x_31', 'x_33', 'x_24', 'x_57', 'x_47', 'x_7', 'x_54', 'x_5', 'x_26', 'x_41', 'x_40', 'x_58', 'x_52', 'x_25', 'x_39', 'x_42', 'x_36', 'x_46', 'x_49', 'x_51', 'x_28'}
# {'x58', 'x38', 'x27', 'x34', 'x6', 'x4', 'x7', 'x8', 'x52', 'x56', 'x9', 'x15', 'x41', 'x54', 'x16', 'x29', 'x20', 'x28', 'x55', 'x47', 'x49', 'x35', 'x11', 'x21', 'x1', 'x10', 'x48', 'x5', 'x17', 'x51', 'x23', 'x25', 'x42', 'x2', 'x13', 'x22', 'x44', 'x40', 'x43', 'x32', 'x19', 'x37', 'x26', 'x39', 'x3', 'x18', 'x50', 'x24', 'x33', 'x14', 'x30', 'x36', 'x45', 'x31', 'x57', 'x46', 'x12', 'x53'}
